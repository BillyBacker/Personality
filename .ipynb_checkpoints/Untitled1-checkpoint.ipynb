# %%
import numba as nb
import numpy as np
from collections import Counter
from numba import jit,cuda, float64
from numpy import genfromtxt,savetxt
import pandas as pd
import math

# %%
prsonallity = genfromtxt("Cleaned.csv",delimiter=' ')
print(prsonallity.shape)
# Out:
# (1013558, 50)

# %%
dataset = prsonallity
pinSet = np.random.rand(2,dataset.shape[1])*scalar
resTensor = np.zeros((dataset.shape[0],pinSet.shape[0]))
resVec = np.zeros(dataset.shape[0])
SumArray = np.zeros((dataset.shape[0],pinSet.shape[0]))
dataset_gpu = cuda.to_device(dataset)
pinSet_gpu = cuda.to_device(pinSet)
resTensor_gpu = cuda.to_device(resTensor)
SumArray_gpu = cuda.to_device(SumArray)
resVec_gpu = cuda.to_device(resVec)

# %%
def genData(k,scalar):
    global dataset, pinSet, resTensor, resVec, SumArray, dataset_gpu, pinSet_gpu, resTensor_gpu, SumArray_gpu, resVec_gpu
    dataset = prsonallity
    pinSet = np.random.rand(k,dataset.shape[1])*scalar
    resTensor = np.zeros((dataset.shape[0],pinSet.shape[0]))
    resVec = np.zeros(dataset.shape[0])
    SumArray = np.zeros((dataset.shape[0],pinSet.shape[0]))
    dataset_gpu = cuda.to_device(dataset)
    pinSet_gpu = cuda.to_device(pinSet)
    resTensor_gpu = cuda.to_device(resTensor)
    SumArray_gpu = cuda.to_device(SumArray)
    resVec_gpu = cuda.to_device(resVec)
def clear():
    global dataset_gpu, pinSet_gpu, resTensor_gpu, SumArray_gpu, resVec_gpu
    dataset_gpu = None
    pinSet_gpu = None
    resTensor_gpu = None
    SumArray_gpu = None
    resVec_gpu = None

# %%
@jit
def getDigit(num):
    k = 0
    while num/(10**k) >= 1:
        k += 1
    return k
@cuda.jit
def subtractPowSum(dataset, pin, resTensor, e):
    x, y = cuda.grid(2)
    if x < resTensor.shape[0] and y < resTensor.shape[1]:
        for n in range(dataset.shape[1]):
            resTensor[x,y] += (dataset[x,n] - pin[y,n])**e
        resTensor[x,y] = resTensor[x,y]**(1/2)
@cuda.jit
def Min(array, resVec):
    x = cuda.grid(1)
    if x < len(resVec):
        MinVar = 999999
        MinIndex = -1
        for k in range(array.shape[1]):
            if MinVar > array[x,k]:
                MinIndex = k
                MinVar = array[x,k]
        resVec[x] = MinIndex
@cuda.jit
def update(pin, minVec, dataset):
    x,y = cuda.grid(2)
    if x < pin.shape[0] and y < pin.shape[1]:
        pin[x,y]  = 0.0
        n = 0.0
        buffer = 0.0
        for i in range(dataset.shape[0]):
            if x == int(minVec[i]):
                buffer = buffer + dataset[i,y]
                n = n + 1.0
        pin[x,y]  = buffer/n

# %%
def findGroup():
#     print('Dataset : \n',dataset_gpu.copy_to_host(),end='\n\n')
    
    tpb = (32,32)
    bpgX = int(math.ceil(dataset_gpu.shape[0]/tpb[0]))
    bpgY = int(math.ceil(dataset_gpu.shape[1]/tpb[1]))
    bpg = (bpgX, bpgY)
    subtractPowSum[bpg,tpb](dataset_gpu, pinSet_gpu, resTensor_gpu,2)
#     print('Subpow : \n',resTensor_gpu.copy_to_host())
    bpgX = int(math.ceil(resTensor_gpu.shape[0]/tpb[0]))
    bpgY = int(math.ceil(resTensor_gpu.shape[1]/tpb[1]))
    bpg = (bpgX, bpgY)
    Min[bpg,tpb](resTensor_gpu, resVec_gpu)
    print('Min : \n',Counter(resVec_gpu.copy_to_host()))
    bpgX = int(math.ceil(pinSet.shape[0]/tpb[0]))
    bpgY = int(math.ceil(pinSet.shape[1]/tpb[1]))
    bpg = (bpgX, bpgY)
#     print('Centroids : \n',pinSet_gpu.copy_to_host(),end='\n\n')
    update[bpg,tpb](pinSet_gpu, resVec_gpu, dataset_gpu)
#     print('Updated centroids : \n',pinSet_gpu.copy_to_host(),end='\n\n')
#     return resVec_gpu.copy_to_host().tolist().count(1.0)

# %%
import timeit
epoch = 1
c = (resVec_gpu.copy_to_host().tolist()).count(1.0)
last_c = -1
print(c, last_c)
while c != last_c:
    delta = c - last_c
    print(f"Epochs : {epoch}, Delta : {delta}")
    epoch += 1
    last_c = c
    c = findGroup()
# Out:
# 0 -1
# Epochs : 1, Delta : 1
# Min :
#  Counter({1.0: 849712, 0.0: 163846})
# Epochs : 2, Delta : 849712
# Min :
#  Counter({1.0: 831641, 0.0: 181917})
# Epochs : 3, Delta : -18071
# Min :
#  Counter({1.0: 811564, 0.0: 201994})
# Epochs : 4, Delta : -20077
# Min :
#  Counter({1.0: 791982, 0.0: 221576})
# Epochs : 5, Delta : -19582
# Min :
#  Counter({1.0: 774032, 0.0: 239526})
# Epochs : 6, Delta : -17950
# Min :
#  Counter({1.0: 758083, 0.0: 255475})
# Epochs : 7, Delta : -15949
# Min :
#  Counter({1.0: 744461, 0.0: 269097})
# Epochs : 8, Delta : -13622
# Min :
#  Counter({1.0: 732357, 0.0: 281201})
# Epochs : 9, Delta : -12104
# Min :
#  Counter({1.0: 721798, 0.0: 291760})
# Epochs : 10, Delta : -10559
# Min :
#  Counter({1.0: 712681, 0.0: 300877})
# Epochs : 11, Delta : -9117
# Min :
#  Counter({1.0: 704703, 0.0: 308855})
# Epochs : 12, Delta : -7978
# Min :
#  Counter({1.0: 697529, 0.0: 316029})
# Epochs : 13, Delta : -7174
# Min :
#  Counter({1.0: 691022, 0.0: 322536})
# Epochs : 14, Delta : -6507
# Min :
#  Counter({1.0: 685039, 0.0: 328519})
# Epochs : 15, Delta : -5983
# Min :
#  Counter({1.0: 679805, 0.0: 333753})
# Epochs : 16, Delta : -5234
# Min :
#  Counter({1.0: 674800, 0.0: 338758})
# Epochs : 17, Delta : -5005
# Min :
#  Counter({1.0: 670327, 0.0: 343231})
# Epochs : 18, Delta : -4473
# Min :
#  Counter({1.0: 666261, 0.0: 347297})
# Epochs : 19, Delta : -4066
# Min :
#  Counter({1.0: 662404, 0.0: 351154})
# Epochs : 20, Delta : -3857
# Min :
#  Counter({1.0: 658960, 0.0: 354598})
# Epochs : 21, Delta : -3444
# Min :
#  Counter({1.0: 655755, 0.0: 357803})
# Epochs : 22, Delta : -3205
# Min :
#  Counter({1.0: 652748, 0.0: 360810})
# Epochs : 23, Delta : -3007
# Min :
#  Counter({1.0: 649826, 0.0: 363732})
# Epochs : 24, Delta : -2922
# Min :
#  Counter({1.0: 647135, 0.0: 366423})
# Epochs : 25, Delta : -2691
# Min :
#  Counter({1.0: 644637, 0.0: 368921})
# Epochs : 26, Delta : -2498
# Min :
#  Counter({1.0: 642189, 0.0: 371369})
# Epochs : 27, Delta : -2448
# Min :
#  Counter({1.0: 640004, 0.0: 373554})
# Epochs : 28, Delta : -2185
# Min :
#  Counter({1.0: 637936, 0.0: 375622})
# Epochs : 29, Delta : -2068
# Min :
#  Counter({1.0: 635920, 0.0: 377638})
# Epochs : 30, Delta : -2016
# Min :
#  Counter({1.0: 633997, 0.0: 379561})
# Epochs : 31, Delta : -1923
# Min :
#  Counter({1.0: 632173, 0.0: 381385})
# Epochs : 32, Delta : -1824
# Min :
#  Counter({1.0: 630361, 0.0: 383197})
# Epochs : 33, Delta : -1812
# Min :
#  Counter({1.0: 628718, 0.0: 384840})
# Epochs : 34, Delta : -1643
# Min :
#  Counter({1.0: 627193, 0.0: 386365})
# Epochs : 35, Delta : -1525
# Min :
#  Counter({1.0: 625583, 0.0: 387975})
# Epochs : 36, Delta : -1610
# Min :
#  Counter({1.0: 624125, 0.0: 389433})
# Epochs : 37, Delta : -1458
# Min :
#  Counter({1.0: 622721, 0.0: 390837})
# Epochs : 38, Delta : -1404
# Min :
#  Counter({1.0: 621349, 0.0: 392209})
# Epochs : 39, Delta : -1372
# Min :
#  Counter({1.0: 620022, 0.0: 393536})
# Epochs : 40, Delta : -1327
# Min :
#  Counter({1.0: 618811, 0.0: 394747})
# Epochs : 41, Delta : -1211
# Min :
#  Counter({1.0: 617699, 0.0: 395859})
# Epochs : 42, Delta : -1112
# Min :
#  Counter({1.0: 616571, 0.0: 396987})
# Epochs : 43, Delta : -1128
# Min :
#  Counter({1.0: 615508, 0.0: 398050})
# Epochs : 44, Delta : -1063
# Min :
#  Counter({1.0: 614428, 0.0: 399130})
# Epochs : 45, Delta : -1080
# Min :
#  Counter({1.0: 613400, 0.0: 400158})
# Epochs : 46, Delta : -1028
# Min :
#  Counter({1.0: 612429, 0.0: 401129})
# Epochs : 47, Delta : -971
# Min :
#  Counter({1.0: 611488, 0.0: 402070})
# Epochs : 48, Delta : -941
# Min :
#  Counter({1.0: 610479, 0.0: 403079})
# Epochs : 49, Delta : -1009
# Min :
#  Counter({1.0: 609651, 0.0: 403907})
# Epochs : 50, Delta : -828
# Min :
#  Counter({1.0: 608801, 0.0: 404757})
# Epochs : 51, Delta : -850
# Min :
#  Counter({1.0: 607917, 0.0: 405641})
# Epochs : 52, Delta : -884
# Min :
#  Counter({1.0: 607152, 0.0: 406406})
# Epochs : 53, Delta : -765
# Min :
#  Counter({1.0: 606420, 0.0: 407138})
# Epochs : 54, Delta : -732
# Min :
#  Counter({1.0: 605683, 0.0: 407875})
# Epochs : 55, Delta : -737
# Min :
#  Counter({1.0: 604924, 0.0: 408634})
# Epochs : 56, Delta : -759
# Min :
#  Counter({1.0: 604127, 0.0: 409431})
# Epochs : 57, Delta : -797
# Min :
#  Counter({1.0: 603510, 0.0: 410048})
# Epochs : 58, Delta : -617
# Min :
#  Counter({1.0: 602765, 0.0: 410793})
# Epochs : 59, Delta : -745
# Min :
#  Counter({1.0: 602155, 0.0: 411403})
# Epochs : 60, Delta : -610
# Min :
#  Counter({1.0: 601458, 0.0: 412100})
# Epochs : 61, Delta : -697
# Min :
#  Counter({1.0: 600847, 0.0: 412711})
# Epochs : 62, Delta : -611
# Min :
#  Counter({1.0: 600157, 0.0: 413401})
# Epochs : 63, Delta : -690
# Min :
#  Counter({1.0: 599526, 0.0: 414032})
# Epochs : 64, Delta : -631
# Min :
#  Counter({1.0: 598925, 0.0: 414633})
# Epochs : 65, Delta : -601
# Min :
#  Counter({1.0: 598364, 0.0: 415194})
# Epochs : 66, Delta : -561
# Min :
#  Counter({1.0: 597859, 0.0: 415699})
# Epochs : 67, Delta : -505
# Min :
#  Counter({1.0: 597287, 0.0: 416271})
# Epochs : 68, Delta : -572
# Min :
#  Counter({1.0: 596792, 0.0: 416766})
# Epochs : 69, Delta : -495
# Min :
#  Counter({1.0: 596224, 0.0: 417334})
# Epochs : 70, Delta : -568
# Min :
#  Counter({1.0: 595680, 0.0: 417878})
# Epochs : 71, Delta : -544
# Min :
#  Counter({1.0: 595163, 0.0: 418395})
# Epochs : 72, Delta : -517
# Min :
#  Counter({1.0: 594656, 0.0: 418902})
# Epochs : 73, Delta : -507
# Min :
#  Counter({1.0: 594168, 0.0: 419390})
# Epochs : 74, Delta : -488
# Min :
#  Counter({1.0: 593658, 0.0: 419900})
# Epochs : 75, Delta : -510
# Min :
#  Counter({1.0: 593161, 0.0: 420397})
# Epochs : 76, Delta : -497
# Min :
#  Counter({1.0: 592720, 0.0: 420838})
# Epochs : 77, Delta : -441
# Min :
#  Counter({1.0: 592252, 0.0: 421306})
# Epochs : 78, Delta : -468
# Min :
#  Counter({1.0: 591806, 0.0: 421752})
# Epochs : 79, Delta : -446
# Min :
#  Counter({1.0: 591342, 0.0: 422216})
# Epochs : 80, Delta : -464
# Min :
#  Counter({1.0: 590918, 0.0: 422640})
# Epochs : 81, Delta : -424
# Min :
#  Counter({1.0: 590524, 0.0: 423034})
# Epochs : 82, Delta : -394
# Min :
#  Counter({1.0: 590125, 0.0: 423433})
# Epochs : 83, Delta : -399
# Min :
#  Counter({1.0: 589713, 0.0: 423845})
# Epochs : 84, Delta : -412
# Min :
#  Counter({1.0: 589272, 0.0: 424286})
# Epochs : 85, Delta : -441
# Min :
#  Counter({1.0: 588831, 0.0: 424727})
# Epochs : 86, Delta : -441
# Min :
#  Counter({1.0: 588429, 0.0: 425129})
# Epochs : 87, Delta : -402
# Min :
#  Counter({1.0: 588035, 0.0: 425523})
# Epochs : 88, Delta : -394
# Min :
#  Counter({1.0: 587668, 0.0: 425890})
# Epochs : 89, Delta : -367
# Min :
#  Counter({1.0: 587326, 0.0: 426232})
# Epochs : 90, Delta : -342
# Min :
#  Counter({1.0: 586991, 0.0: 426567})
# Epochs : 91, Delta : -335
# Min :
#  Counter({1.0: 586670, 0.0: 426888})
# Epochs : 92, Delta : -321
# Min :
#  Counter({1.0: 586394, 0.0: 427164})
# Epochs : 93, Delta : -276
# Min :
#  Counter({1.0: 586037, 0.0: 427521})
# Epochs : 94, Delta : -357
# Min :
#  Counter({1.0: 585665, 0.0: 427893})
# Epochs : 95, Delta : -372
# Min :
#  Counter({1.0: 585343, 0.0: 428215})
# Epochs : 96, Delta : -322
# Min :
#  Counter({1.0: 584997, 0.0: 428561})
# Epochs : 97, Delta : -346
# Min :
#  Counter({1.0: 584660, 0.0: 428898})
# Epochs : 98, Delta : -337
# Min :
#  Counter({1.0: 584369, 0.0: 429189})
# Epochs : 99, Delta : -291
# Min :
#  Counter({1.0: 584070, 0.0: 429488})
# Epochs : 100, Delta : -299
# Min :
#  Counter({1.0: 583771, 0.0: 429787})
# Epochs : 101, Delta : -299
# Min :
#  Counter({1.0: 583483, 0.0: 430075})
# Epochs : 102, Delta : -288
# Min :
#  Counter({1.0: 583164, 0.0: 430394})
# Epochs : 103, Delta : -319
# Min :
#  Counter({1.0: 582814, 0.0: 430744})
# Epochs : 104, Delta : -350
# Min :
#  Counter({1.0: 582530, 0.0: 431028})
# Epochs : 105, Delta : -284
# Min :
#  Counter({1.0: 582269, 0.0: 431289})
# Epochs : 106, Delta : -261
# Min :
#  Counter({1.0: 581966, 0.0: 431592})
# Epochs : 107, Delta : -303
# Min :
#  Counter({1.0: 581681, 0.0: 431877})
# Epochs : 108, Delta : -285
# Min :
#  Counter({1.0: 581459, 0.0: 432099})
# Epochs : 109, Delta : -222
# Min :
#  Counter({1.0: 581170, 0.0: 432388})
# Epochs : 110, Delta : -289
# Min :
#  Counter({1.0: 580911, 0.0: 432647})
# Epochs : 111, Delta : -259
# Min :
#  Counter({1.0: 580654, 0.0: 432904})
# Epochs : 112, Delta : -257
# Min :
#  Counter({1.0: 580373, 0.0: 433185})
# Epochs : 113, Delta : -281
# Min :
#  Counter({1.0: 580139, 0.0: 433419})
# Epochs : 114, Delta : -234
# Min :
#  Counter({1.0: 579899, 0.0: 433659})
# Epochs : 115, Delta : -240
# Min :
#  Counter({1.0: 579633, 0.0: 433925})
# Epochs : 116, Delta : -266
# Min :
#  Counter({1.0: 579438, 0.0: 434120})
# Epochs : 117, Delta : -195
# Min :
#  Counter({1.0: 579222, 0.0: 434336})
# Epochs : 118, Delta : -216
# Min :
#  Counter({1.0: 578964, 0.0: 434594})
# Epochs : 119, Delta : -258
# Min :
#  Counter({1.0: 578748, 0.0: 434810})
# Epochs : 120, Delta : -216
# Min :
#  Counter({1.0: 578525, 0.0: 435033})
# Epochs : 121, Delta : -223
# Min :
#  Counter({1.0: 578275, 0.0: 435283})
# Epochs : 122, Delta : -250
# Min :
#  Counter({1.0: 577986, 0.0: 435572})
# Epochs : 123, Delta : -289
# Min :
#  Counter({1.0: 577789, 0.0: 435769})
# Epochs : 124, Delta : -197
# Min :
#  Counter({1.0: 577521, 0.0: 436037})
# Epochs : 125, Delta : -268
# Min :
#  Counter({1.0: 577352, 0.0: 436206})
# Epochs : 126, Delta : -169
# Min :
#  Counter({1.0: 577123, 0.0: 436435})
# Epochs : 127, Delta : -229
# Min :
#  Counter({1.0: 576901, 0.0: 436657})
# Epochs : 128, Delta : -222
# Min :
#  Counter({1.0: 576684, 0.0: 436874})
# Epochs : 129, Delta : -217
# Min :
#  Counter({1.0: 576483, 0.0: 437075})
# Epochs : 130, Delta : -201
# Min :
#  Counter({1.0: 576262, 0.0: 437296})
# Epochs : 131, Delta : -221
# Min :
#  Counter({1.0: 576083, 0.0: 437475})
# Epochs : 132, Delta : -179
# Min :
#  Counter({1.0: 575854, 0.0: 437704})
# Epochs : 133, Delta : -229
# Min :
#  Counter({1.0: 575664, 0.0: 437894})
# Epochs : 134, Delta : -190
# Min :
#  Counter({1.0: 575490, 0.0: 438068})
# Epochs : 135, Delta : -174
# Min :
#  Counter({1.0: 575309, 0.0: 438249})
# Epochs : 136, Delta : -181
# Min :
#  Counter({1.0: 575103, 0.0: 438455})
# Epochs : 137, Delta : -206
# Min :
#  Counter({1.0: 574901, 0.0: 438657})
# Epochs : 138, Delta : -202
# Min :
#  Counter({1.0: 574693, 0.0: 438865})
# Epochs : 139, Delta : -208
# Min :
#  Counter({1.0: 574529, 0.0: 439029})
# Epochs : 140, Delta : -164
# Min :
#  Counter({1.0: 574355, 0.0: 439203})
# Epochs : 141, Delta : -174
# Min :
#  Counter({1.0: 574225, 0.0: 439333})
# Epochs : 142, Delta : -130
# Min :
#  Counter({1.0: 574047, 0.0: 439511})
# Epochs : 143, Delta : -178
# Min :
#  Counter({1.0: 573816, 0.0: 439742})
# Epochs : 144, Delta : -231
# Min :
#  Counter({1.0: 573647, 0.0: 439911})
# Epochs : 145, Delta : -169
# Min :
#  Counter({1.0: 573471, 0.0: 440087})
# Epochs : 146, Delta : -176
# Min :
#  Counter({1.0: 573266, 0.0: 440292})
# Epochs : 147, Delta : -205
# Min :
#  Counter({1.0: 573099, 0.0: 440459})
# Epochs : 148, Delta : -167
# Min :
#  Counter({1.0: 572960, 0.0: 440598})
# Epochs : 149, Delta : -139
# Min :
#  Counter({1.0: 572796, 0.0: 440762})
# Epochs : 150, Delta : -164
# Min :
#  Counter({1.0: 572657, 0.0: 440901})
# Epochs : 151, Delta : -139
# Min :
#  Counter({1.0: 572470, 0.0: 441088})
# Epochs : 152, Delta : -187
# Min :
#  Counter({1.0: 572304, 0.0: 441254})
# Epochs : 153, Delta : -166
# Min :
#  Counter({1.0: 572154, 0.0: 441404})
# Epochs : 154, Delta : -150
# Min :
#  Counter({1.0: 572007, 0.0: 441551})
# Epochs : 155, Delta : -147
# Min :
#  Counter({1.0: 571866, 0.0: 441692})
# Epochs : 156, Delta : -141
# Min :
#  Counter({1.0: 571721, 0.0: 441837})
# Epochs : 157, Delta : -145
# Min :
#  Counter({1.0: 571565, 0.0: 441993})
# Epochs : 158, Delta : -156
# Min :
#  Counter({1.0: 571393, 0.0: 442165})
# Epochs : 159, Delta : -172
# Min :
#  Counter({1.0: 571264, 0.0: 442294})
# Epochs : 160, Delta : -129
# Min :
#  Counter({1.0: 571113, 0.0: 442445})
# Epochs : 161, Delta : -151
# Min :
#  Counter({1.0: 570998, 0.0: 442560})
# Epochs : 162, Delta : -115
# Min :
#  Counter({1.0: 570841, 0.0: 442717})
# Epochs : 163, Delta : -157
# Min :
#  Counter({1.0: 570691, 0.0: 442867})
# Epochs : 164, Delta : -150
# Min :
#  Counter({1.0: 570540, 0.0: 443018})
# Epochs : 165, Delta : -151
# Min :
#  Counter({1.0: 570418, 0.0: 443140})
# Epochs : 166, Delta : -122
# Min :
#  Counter({1.0: 570267, 0.0: 443291})
# Epochs : 167, Delta : -151
# Min :
#  Counter({1.0: 570147, 0.0: 443411})
# Epochs : 168, Delta : -120
# Min :
#  Counter({1.0: 570008, 0.0: 443550})
# Epochs : 169, Delta : -139
# Min :
#  Counter({1.0: 569880, 0.0: 443678})
# Epochs : 170, Delta : -128
# Min :
#  Counter({1.0: 569703, 0.0: 443855})
# Epochs : 171, Delta : -177
# Min :
#  Counter({1.0: 569533, 0.0: 444025})
# Epochs : 172, Delta : -170
# Min :
#  Counter({1.0: 569399, 0.0: 444159})
# Epochs : 173, Delta : -134
# Min :
#  Counter({1.0: 569265, 0.0: 444293})
# Epochs : 174, Delta : -134
# Min :
#  Counter({1.0: 569117, 0.0: 444441})
# Epochs : 175, Delta : -148
# Min :
#  Counter({1.0: 568978, 0.0: 444580})
# Epochs : 176, Delta : -139
# Min :
#  Counter({1.0: 568842, 0.0: 444716})
# Epochs : 177, Delta : -136
# Min :
#  Counter({1.0: 568701, 0.0: 444857})
# Epochs : 178, Delta : -141
# Min :
#  Counter({1.0: 568572, 0.0: 444986})
# Epochs : 179, Delta : -129
# Min :
#  Counter({1.0: 568432, 0.0: 445126})
# Epochs : 180, Delta : -140
# Min :
#  Counter({1.0: 568320, 0.0: 445238})
# Epochs : 181, Delta : -112
# Min :
#  Counter({1.0: 568175, 0.0: 445383})
# Epochs : 182, Delta : -145
# Min :
#  Counter({1.0: 568059, 0.0: 445499})
# Epochs : 183, Delta : -116
# Min :
#  Counter({1.0: 567955, 0.0: 445603})
# Epochs : 184, Delta : -104
# Min :
#  Counter({1.0: 567839, 0.0: 445719})
# Epochs : 185, Delta : -116
# Min :
#  Counter({1.0: 567703, 0.0: 445855})
# Epochs : 186, Delta : -136
# Min :
#  Counter({1.0: 567581, 0.0: 445977})
# Epochs : 187, Delta : -122
# Min :
#  Counter({1.0: 567463, 0.0: 446095})
# Epochs : 188, Delta : -118
# Min :
#  Counter({1.0: 567337, 0.0: 446221})
# Epochs : 189, Delta : -126
# Min :
#  Counter({1.0: 567228, 0.0: 446330})
# Epochs : 190, Delta : -109
# Min :
#  Counter({1.0: 567097, 0.0: 446461})
# Epochs : 191, Delta : -131
# Min :
#  Counter({1.0: 566978, 0.0: 446580})
# Epochs : 192, Delta : -119
# Min :
#  Counter({1.0: 566868, 0.0: 446690})
# Epochs : 193, Delta : -110
# Min :
#  Counter({1.0: 566746, 0.0: 446812})
# Epochs : 194, Delta : -122
# Min :
#  Counter({1.0: 566655, 0.0: 446903})
# Epochs : 195, Delta : -91
# Min :
#  Counter({1.0: 566524, 0.0: 447034})
# Epochs : 196, Delta : -131
# Min :
#  Counter({1.0: 566424, 0.0: 447134})
# Epochs : 197, Delta : -100
# Min :
#  Counter({1.0: 566296, 0.0: 447262})
# Epochs : 198, Delta : -128
# Min :
#  Counter({1.0: 566219, 0.0: 447339})
# Epochs : 199, Delta : -77
# Min :
#  Counter({1.0: 566115, 0.0: 447443})
# Epochs : 200, Delta : -104
# Min :
#  Counter({1.0: 566018, 0.0: 447540})
# Epochs : 201, Delta : -97
# Min :
#  Counter({1.0: 565913, 0.0: 447645})
# Epochs : 202, Delta : -105
# Min :
#  Counter({1.0: 565820, 0.0: 447738})
# Epochs : 203, Delta : -93
# Min :
#  Counter({1.0: 565713, 0.0: 447845})
# Epochs : 204, Delta : -107
# Min :
#  Counter({1.0: 565600, 0.0: 447958})
# Epochs : 205, Delta : -113
# Min :
#  Counter({1.0: 565469, 0.0: 448089})
# Epochs : 206, Delta : -131
# Min :
#  Counter({1.0: 565361, 0.0: 448197})
# Epochs : 207, Delta : -108
# Min :
#  Counter({1.0: 565253, 0.0: 448305})
# Epochs : 208, Delta : -108
# Min :
#  Counter({1.0: 565154, 0.0: 448404})
# Epochs : 209, Delta : -99
# Min :
#  Counter({1.0: 565047, 0.0: 448511})
# Epochs : 210, Delta : -107
# Min :
#  Counter({1.0: 564920, 0.0: 448638})
# Epochs : 211, Delta : -127
# Min :
#  Counter({1.0: 564790, 0.0: 448768})
# Epochs : 212, Delta : -130
# Min :
#  Counter({1.0: 564697, 0.0: 448861})
# Epochs : 213, Delta : -93
# Min :
#  Counter({1.0: 564629, 0.0: 448929})
# Epochs : 214, Delta : -68
# Min :
#  Counter({1.0: 564523, 0.0: 449035})
# Epochs : 215, Delta : -106
# Min :
#  Counter({1.0: 564425, 0.0: 449133})
# Epochs : 216, Delta : -98
# Min :
#  Counter({1.0: 564342, 0.0: 449216})
# Epochs : 217, Delta : -83
# Min :
#  Counter({1.0: 564235, 0.0: 449323})
# Epochs : 218, Delta : -107
# Min :
#  Counter({1.0: 564123, 0.0: 449435})
# Epochs : 219, Delta : -112
# Min :
#  Counter({1.0: 564024, 0.0: 449534})
# Epochs : 220, Delta : -99
# Min :
#  Counter({1.0: 563932, 0.0: 449626})
# Epochs : 221, Delta : -92
# Min :
#  Counter({1.0: 563845, 0.0: 449713})
# Epochs : 222, Delta : -87
# Min :
#  Counter({1.0: 563786, 0.0: 449772})
# Epochs : 223, Delta : -59
# Min :
#  Counter({1.0: 563695, 0.0: 449863})
# Epochs : 224, Delta : -91
# Min :
#  Counter({1.0: 563590, 0.0: 449968})
# Epochs : 225, Delta : -105
# Min :
#  Counter({1.0: 563490, 0.0: 450068})
# Epochs : 226, Delta : -100
# Min :
#  Counter({1.0: 563376, 0.0: 450182})
# Epochs : 227, Delta : -114
# Min :
#  Counter({1.0: 563273, 0.0: 450285})
# Epochs : 228, Delta : -103
# Min :
#  Counter({1.0: 563199, 0.0: 450359})
# Epochs : 229, Delta : -74
# Min :
#  Counter({1.0: 563095, 0.0: 450463})
# Epochs : 230, Delta : -104
# Min :
#  Counter({1.0: 563013, 0.0: 450545})
# Epochs : 231, Delta : -82
# Min :
#  Counter({1.0: 562923, 0.0: 450635})
# Epochs : 232, Delta : -90
# Min :
#  Counter({1.0: 562842, 0.0: 450716})
# Epochs : 233, Delta : -81
# Min :
#  Counter({1.0: 562724, 0.0: 450834})
# Epochs : 234, Delta : -118
# Min :
#  Counter({1.0: 562655, 0.0: 450903})
# Epochs : 235, Delta : -69
# Min :
#  Counter({1.0: 562571, 0.0: 450987})
# Epochs : 236, Delta : -84
# Min :
#  Counter({1.0: 562475, 0.0: 451083})
# Epochs : 237, Delta : -96
# Min :
#  Counter({1.0: 562390, 0.0: 451168})
# Epochs : 238, Delta : -85
# Min :
#  Counter({1.0: 562306, 0.0: 451252})
# Epochs : 239, Delta : -84
# Min :
#  Counter({1.0: 562234, 0.0: 451324})
# Epochs : 240, Delta : -72
# Min :
#  Counter({1.0: 562146, 0.0: 451412})
# Epochs : 241, Delta : -88
# Min :
#  Counter({1.0: 562070, 0.0: 451488})
# Epochs : 242, Delta : -76
# Min :
#  Counter({1.0: 561990, 0.0: 451568})
# Epochs : 243, Delta : -80
# Min :
#  Counter({1.0: 561914, 0.0: 451644})
# Epochs : 244, Delta : -76
# Min :
#  Counter({1.0: 561810, 0.0: 451748})
# Epochs : 245, Delta : -104
# Min :
#  Counter({1.0: 561727, 0.0: 451831})
# Epochs : 246, Delta : -83
# Min :
#  Counter({1.0: 561639, 0.0: 451919})
# Epochs : 247, Delta : -88
# Min :
#  Counter({1.0: 561579, 0.0: 451979})
# Epochs : 248, Delta : -60
# Min :
#  Counter({1.0: 561510, 0.0: 452048})
# Epochs : 249, Delta : -69
# Min :
#  Counter({1.0: 561443, 0.0: 452115})
# Epochs : 250, Delta : -67
# Min :
#  Counter({1.0: 561347, 0.0: 452211})
# Epochs : 251, Delta : -96
# Min :
#  Counter({1.0: 561247, 0.0: 452311})
# Epochs : 252, Delta : -100
# Min :
#  Counter({1.0: 561205, 0.0: 452353})
# Epochs : 253, Delta : -42
# Min :
#  Counter({1.0: 561126, 0.0: 452432})
# Epochs : 254, Delta : -79
# Min :
#  Counter({1.0: 561040, 0.0: 452518})
# Epochs : 255, Delta : -86
# Min :
#  Counter({1.0: 560983, 0.0: 452575})
# Epochs : 256, Delta : -57
# Min :
#  Counter({1.0: 560898, 0.0: 452660})
# Epochs : 257, Delta : -85
# Min :
#  Counter({1.0: 560847, 0.0: 452711})
# Epochs : 258, Delta : -51
# Min :
#  Counter({1.0: 560764, 0.0: 452794})
# Epochs : 259, Delta : -83
# Min :
#  Counter({1.0: 560699, 0.0: 452859})
# Epochs : 260, Delta : -65
# Min :
#  Counter({1.0: 560611, 0.0: 452947})
# Epochs : 261, Delta : -88
# Min :
#  Counter({1.0: 560548, 0.0: 453010})
# Epochs : 262, Delta : -63
# Min :
#  Counter({1.0: 560458, 0.0: 453100})
# Epochs : 263, Delta : -90
# Min :
#  Counter({1.0: 560371, 0.0: 453187})
# Epochs : 264, Delta : -87
# Min :
#  Counter({1.0: 560301, 0.0: 453257})
# Epochs : 265, Delta : -70
# Min :
#  Counter({1.0: 560209, 0.0: 453349})
# Epochs : 266, Delta : -92
# Min :
#  Counter({1.0: 560161, 0.0: 453397})
# Epochs : 267, Delta : -48
# Min :
#  Counter({1.0: 560092, 0.0: 453466})
# Epochs : 268, Delta : -69
# Min :
#  Counter({1.0: 560024, 0.0: 453534})
# Epochs : 269, Delta : -68
# Min :
#  Counter({1.0: 559960, 0.0: 453598})
# Epochs : 270, Delta : -64
# Min :
#  Counter({1.0: 559869, 0.0: 453689})
# Epochs : 271, Delta : -91
# Min :
#  Counter({1.0: 559768, 0.0: 453790})
# Epochs : 272, Delta : -101
# Min :
#  Counter({1.0: 559693, 0.0: 453865})
# Epochs : 273, Delta : -75
# Min :
#  Counter({1.0: 559649, 0.0: 453909})
# Epochs : 274, Delta : -44
# Min :
#  Counter({1.0: 559584, 0.0: 453974})
# Epochs : 275, Delta : -65
# Min :
#  Counter({1.0: 559529, 0.0: 454029})
# Epochs : 276, Delta : -55
# Min :
#  Counter({1.0: 559461, 0.0: 454097})
# Epochs : 277, Delta : -68
# Min :
#  Counter({1.0: 559391, 0.0: 454167})
# Epochs : 278, Delta : -70
# Min :
#  Counter({1.0: 559318, 0.0: 454240})
# Epochs : 279, Delta : -73
# Min :
#  Counter({1.0: 559236, 0.0: 454322})
# Epochs : 280, Delta : -82
# Min :
#  Counter({1.0: 559185, 0.0: 454373})
# Epochs : 281, Delta : -51
# Min :
#  Counter({1.0: 559105, 0.0: 454453})
# Epochs : 282, Delta : -80
# Min :
#  Counter({1.0: 559028, 0.0: 454530})
# Epochs : 283, Delta : -77
# Min :
#  Counter({1.0: 558975, 0.0: 454583})
# Epochs : 284, Delta : -53
# Min :
#  Counter({1.0: 558926, 0.0: 454632})
# Epochs : 285, Delta : -49
# Min :
#  Counter({1.0: 558858, 0.0: 454700})
# Epochs : 286, Delta : -68
# Min :
#  Counter({1.0: 558782, 0.0: 454776})
# Epochs : 287, Delta : -76
# Min :
#  Counter({1.0: 558730, 0.0: 454828})
# Epochs : 288, Delta : -52
# Min :
#  Counter({1.0: 558673, 0.0: 454885})
# Epochs : 289, Delta : -57
# Min :
#  Counter({1.0: 558616, 0.0: 454942})
# Epochs : 290, Delta : -57
# Min :
#  Counter({1.0: 558567, 0.0: 454991})
# Epochs : 291, Delta : -49
# Min :
#  Counter({1.0: 558501, 0.0: 455057})
# Epochs : 292, Delta : -66
# Min :
#  Counter({1.0: 558453, 0.0: 455105})
# Epochs : 293, Delta : -48
# Min :
#  Counter({1.0: 558367, 0.0: 455191})
# Epochs : 294, Delta : -86
# Min :
#  Counter({1.0: 558311, 0.0: 455247})
# Epochs : 295, Delta : -56
# Min :
#  Counter({1.0: 558257, 0.0: 455301})
# Epochs : 296, Delta : -54
# Min :
#  Counter({1.0: 558215, 0.0: 455343})
# Epochs : 297, Delta : -42
# Min :
#  Counter({1.0: 558157, 0.0: 455401})
# Epochs : 298, Delta : -58
# Min :
#  Counter({1.0: 558085, 0.0: 455473})
# Epochs : 299, Delta : -72
# Min :
#  Counter({1.0: 558021, 0.0: 455537})
# Epochs : 300, Delta : -64
# Min :
#  Counter({1.0: 557980, 0.0: 455578})
# Epochs : 301, Delta : -41
# Min :
#  Counter({1.0: 557922, 0.0: 455636})
# Epochs : 302, Delta : -58
# Min :
#  Counter({1.0: 557881, 0.0: 455677})
# Epochs : 303, Delta : -41
# Min :
#  Counter({1.0: 557817, 0.0: 455741})
# Epochs : 304, Delta : -64
# Min :
#  Counter({1.0: 557777, 0.0: 455781})
# Epochs : 305, Delta : -40
# Min :
#  Counter({1.0: 557756, 0.0: 455802})
# Epochs : 306, Delta : -21
# Min :
#  Counter({1.0: 557687, 0.0: 455871})
# Epochs : 307, Delta : -69
# Min :
#  Counter({1.0: 557624, 0.0: 455934})
# Epochs : 308, Delta : -63
# Min :
#  Counter({1.0: 557571, 0.0: 455987})
# Epochs : 309, Delta : -53
# Min :
#  Counter({1.0: 557494, 0.0: 456064})
# Epochs : 310, Delta : -77
# Min :
#  Counter({1.0: 557448, 0.0: 456110})
# Epochs : 311, Delta : -46
# Min :
#  Counter({1.0: 557395, 0.0: 456163})
# Epochs : 312, Delta : -53
# Min :
#  Counter({1.0: 557339, 0.0: 456219})
# Epochs : 313, Delta : -56
# Min :
#  Counter({1.0: 557297, 0.0: 456261})
# Epochs : 314, Delta : -42
# Min :
#  Counter({1.0: 557242, 0.0: 456316})
# Epochs : 315, Delta : -55
# Min :
#  Counter({1.0: 557159, 0.0: 456399})
# Epochs : 316, Delta : -83
# Min :
#  Counter({1.0: 557103, 0.0: 456455})
# Epochs : 317, Delta : -56
# Min :
#  Counter({1.0: 557048, 0.0: 456510})
# Epochs : 318, Delta : -55
# Min :
#  Counter({1.0: 557001, 0.0: 456557})
# Epochs : 319, Delta : -47
# Min :
#  Counter({1.0: 556952, 0.0: 456606})
# Epochs : 320, Delta : -49
# Min :
#  Counter({1.0: 556913, 0.0: 456645})
# Epochs : 321, Delta : -39
# Min :
#  Counter({1.0: 556849, 0.0: 456709})
# Epochs : 322, Delta : -64
# Min :
#  Counter({1.0: 556790, 0.0: 456768})
# Epochs : 323, Delta : -59
# Min :
#  Counter({1.0: 556742, 0.0: 456816})
# Epochs : 324, Delta : -48
# Min :
#  Counter({1.0: 556681, 0.0: 456877})
# Epochs : 325, Delta : -61
# Min :
#  Counter({1.0: 556648, 0.0: 456910})
# Epochs : 326, Delta : -33
# Min :
#  Counter({1.0: 556612, 0.0: 456946})
# Epochs : 327, Delta : -36
# Min :
#  Counter({1.0: 556554, 0.0: 457004})
# Epochs : 328, Delta : -58
# Min :
#  Counter({1.0: 556513, 0.0: 457045})
# Epochs : 329, Delta : -41
# Min :
#  Counter({1.0: 556441, 0.0: 457117})
# Epochs : 330, Delta : -72
# Min :
#  Counter({1.0: 556395, 0.0: 457163})
# Epochs : 331, Delta : -46
# Min :
#  Counter({1.0: 556339, 0.0: 457219})
# Epochs : 332, Delta : -56
# Min :
#  Counter({1.0: 556309, 0.0: 457249})
# Epochs : 333, Delta : -30
# Min :
#  Counter({1.0: 556262, 0.0: 457296})
# Epochs : 334, Delta : -47
# Min :
#  Counter({1.0: 556198, 0.0: 457360})
# Epochs : 335, Delta : -64
# Min :
#  Counter({1.0: 556159, 0.0: 457399})
# Epochs : 336, Delta : -39
# Min :
#  Counter({1.0: 556116, 0.0: 457442})
# Epochs : 337, Delta : -43
# Min :
#  Counter({1.0: 556063, 0.0: 457495})
# Epochs : 338, Delta : -53
# Min :
#  Counter({1.0: 556030, 0.0: 457528})
# Epochs : 339, Delta : -33
# Min :
#  Counter({1.0: 555981, 0.0: 457577})
# Epochs : 340, Delta : -49
# Min :
#  Counter({1.0: 555951, 0.0: 457607})
# Epochs : 341, Delta : -30
# Min :
#  Counter({1.0: 555929, 0.0: 457629})
# Epochs : 342, Delta : -22
# Min :
#  Counter({1.0: 555872, 0.0: 457686})
# Epochs : 343, Delta : -57
# Min :
#  Counter({1.0: 555820, 0.0: 457738})
# Epochs : 344, Delta : -52
# Min :
#  Counter({1.0: 555776, 0.0: 457782})
# Epochs : 345, Delta : -44
# Min :
#  Counter({1.0: 555721, 0.0: 457837})
# Epochs : 346, Delta : -55
# Min :
#  Counter({1.0: 555675, 0.0: 457883})
# Epochs : 347, Delta : -46
# Min :
#  Counter({1.0: 555618, 0.0: 457940})
# Epochs : 348, Delta : -57
# Min :
#  Counter({1.0: 555562, 0.0: 457996})
# Epochs : 349, Delta : -56
# Min :
#  Counter({1.0: 555517, 0.0: 458041})
# Epochs : 350, Delta : -45
# Min :
#  Counter({1.0: 555479, 0.0: 458079})
# Epochs : 351, Delta : -38
# Min :
#  Counter({1.0: 555431, 0.0: 458127})
# Epochs : 352, Delta : -48
# Min :
#  Counter({1.0: 555384, 0.0: 458174})
# Epochs : 353, Delta : -47
# Min :
#  Counter({1.0: 555329, 0.0: 458229})
# Epochs : 354, Delta : -55
# Min :
#  Counter({1.0: 555299, 0.0: 458259})
# Epochs : 355, Delta : -30
# Min :
#  Counter({1.0: 555253, 0.0: 458305})
# Epochs : 356, Delta : -46
# Min :
#  Counter({1.0: 555197, 0.0: 458361})
# Epochs : 357, Delta : -56
# Min :
#  Counter({1.0: 555163, 0.0: 458395})
# Epochs : 358, Delta : -34
# Min :
#  Counter({1.0: 555135, 0.0: 458423})
# Epochs : 359, Delta : -28
# Min :
#  Counter({1.0: 555118, 0.0: 458440})
# Epochs : 360, Delta : -17
# Min :
#  Counter({1.0: 555060, 0.0: 458498})
# Epochs : 361, Delta : -58
# Min :
#  Counter({1.0: 555031, 0.0: 458527})
# Epochs : 362, Delta : -29
# Min :
#  Counter({1.0: 554993, 0.0: 458565})
# Epochs : 363, Delta : -38
# Min :
#  Counter({1.0: 554955, 0.0: 458603})
# Epochs : 364, Delta : -38
# Min :
#  Counter({1.0: 554901, 0.0: 458657})
# Epochs : 365, Delta : -54
# Min :
#  Counter({1.0: 554861, 0.0: 458697})
# Epochs : 366, Delta : -40
# Min :
#  Counter({1.0: 554814, 0.0: 458744})
# Epochs : 367, Delta : -47
# Min :
#  Counter({1.0: 554762, 0.0: 458796})
# Epochs : 368, Delta : -52
# Min :
#  Counter({1.0: 554718, 0.0: 458840})
# Epochs : 369, Delta : -44
# Min :
#  Counter({1.0: 554656, 0.0: 458902})
# Epochs : 370, Delta : -62
# Min :
#  Counter({1.0: 554613, 0.0: 458945})
# Epochs : 371, Delta : -43
# Min :
#  Counter({1.0: 554558, 0.0: 459000})
# Epochs : 372, Delta : -55
# Min :
#  Counter({1.0: 554505, 0.0: 459053})
# Epochs : 373, Delta : -53
# Min :
#  Counter({1.0: 554471, 0.0: 459087})
# Epochs : 374, Delta : -34
# Min :
#  Counter({1.0: 554441, 0.0: 459117})
# Epochs : 375, Delta : -30
# Min :
#  Counter({1.0: 554399, 0.0: 459159})
# Epochs : 376, Delta : -42
# Min :
#  Counter({1.0: 554351, 0.0: 459207})
# Epochs : 377, Delta : -48
# Min :
#  Counter({1.0: 554315, 0.0: 459243})
# Epochs : 378, Delta : -36
# Min :
#  Counter({1.0: 554285, 0.0: 459273})
# Epochs : 379, Delta : -30
# Min :
#  Counter({1.0: 554230, 0.0: 459328})
# Epochs : 380, Delta : -55
# Min :
#  Counter({1.0: 554191, 0.0: 459367})
# Epochs : 381, Delta : -39
# Min :
#  Counter({1.0: 554152, 0.0: 459406})
# Epochs : 382, Delta : -39
# Min :
#  Counter({1.0: 554103, 0.0: 459455})
# Epochs : 383, Delta : -49
# Min :
#  Counter({1.0: 554061, 0.0: 459497})
# Epochs : 384, Delta : -42
# Min :
#  Counter({1.0: 554020, 0.0: 459538})
# Epochs : 385, Delta : -41
# Min :
#  Counter({1.0: 553988, 0.0: 459570})
# Epochs : 386, Delta : -32
# Min :
#  Counter({1.0: 553953, 0.0: 459605})
# Epochs : 387, Delta : -35
# Min :
#  Counter({1.0: 553925, 0.0: 459633})
# Epochs : 388, Delta : -28
# Min :
#  Counter({1.0: 553896, 0.0: 459662})
# Epochs : 389, Delta : -29
# Min :
#  Counter({1.0: 553864, 0.0: 459694})
# Epochs : 390, Delta : -32
# Min :
#  Counter({1.0: 553825, 0.0: 459733})
# Epochs : 391, Delta : -39
# Min :
#  Counter({1.0: 553791, 0.0: 459767})
# Epochs : 392, Delta : -34
# Min :
#  Counter({1.0: 553752, 0.0: 459806})
# Epochs : 393, Delta : -39
# Min :
#  Counter({1.0: 553739, 0.0: 459819})
# Epochs : 394, Delta : -13
# Min :
#  Counter({1.0: 553691, 0.0: 459867})
# Epochs : 395, Delta : -48
# Min :
#  Counter({1.0: 553652, 0.0: 459906})
# Epochs : 396, Delta : -39
# Min :
#  Counter({1.0: 553613, 0.0: 459945})
# Epochs : 397, Delta : -39
# Min :
#  Counter({1.0: 553581, 0.0: 459977})
# Epochs : 398, Delta : -32
# Min :
#  Counter({1.0: 553548, 0.0: 460010})
# Epochs : 399, Delta : -33
# Min :
#  Counter({1.0: 553512, 0.0: 460046})
# Epochs : 400, Delta : -36
# Min :
#  Counter({1.0: 553459, 0.0: 460099})
# Epochs : 401, Delta : -53
# Min :
#  Counter({1.0: 553421, 0.0: 460137})
# Epochs : 402, Delta : -38
# Min :
#  Counter({1.0: 553396, 0.0: 460162})
# Epochs : 403, Delta : -25
# Min :
#  Counter({1.0: 553368, 0.0: 460190})
# Epochs : 404, Delta : -28
# Min :
#  Counter({1.0: 553335, 0.0: 460223})
# Epochs : 405, Delta : -33
# Min :
#  Counter({1.0: 553294, 0.0: 460264})
# Epochs : 406, Delta : -41
# Min :
#  Counter({1.0: 553258, 0.0: 460300})
# Epochs : 407, Delta : -36
# Min :
#  Counter({1.0: 553213, 0.0: 460345})
# Epochs : 408, Delta : -45
# Min :
#  Counter({1.0: 553182, 0.0: 460376})
# Epochs : 409, Delta : -31
# Min :
#  Counter({1.0: 553138, 0.0: 460420})
# Epochs : 410, Delta : -44
# Min :
#  Counter({1.0: 553114, 0.0: 460444})
# Epochs : 411, Delta : -24
# Min :
#  Counter({1.0: 553076, 0.0: 460482})
# Epochs : 412, Delta : -38
# Min :
#  Counter({1.0: 553066, 0.0: 460492})
# Epochs : 413, Delta : -10
# Min :
#  Counter({1.0: 553041, 0.0: 460517})
# Epochs : 414, Delta : -25
# Min :
#  Counter({1.0: 553022, 0.0: 460536})
# Epochs : 415, Delta : -19
# Min :
#  Counter({1.0: 552997, 0.0: 460561})
# Epochs : 416, Delta : -25
# Min :
#  Counter({1.0: 552958, 0.0: 460600})
# Epochs : 417, Delta : -39
# Min :
#  Counter({1.0: 552930, 0.0: 460628})
# Epochs : 418, Delta : -28
# Min :
#  Counter({1.0: 552886, 0.0: 460672})
# Epochs : 419, Delta : -44
# Min :
#  Counter({1.0: 552866, 0.0: 460692})
# Epochs : 420, Delta : -20
# Min :
#  Counter({1.0: 552826, 0.0: 460732})
# Epochs : 421, Delta : -40
# Min :
#  Counter({1.0: 552792, 0.0: 460766})
# Epochs : 422, Delta : -34
# Min :
#  Counter({1.0: 552746, 0.0: 460812})
# Epochs : 423, Delta : -46
# Min :
#  Counter({1.0: 552721, 0.0: 460837})
# Epochs : 424, Delta : -25
# Min :
#  Counter({1.0: 552693, 0.0: 460865})
# Epochs : 425, Delta : -28
# Min :
#  Counter({1.0: 552641, 0.0: 460917})
# Epochs : 426, Delta : -52
# Min :
#  Counter({1.0: 552609, 0.0: 460949})
# Epochs : 427, Delta : -32
# Min :
#  Counter({1.0: 552566, 0.0: 460992})
# Epochs : 428, Delta : -43
# Min :
#  Counter({1.0: 552536, 0.0: 461022})
# Epochs : 429, Delta : -30
# Min :
#  Counter({1.0: 552501, 0.0: 461057})
# Epochs : 430, Delta : -35
# Min :
#  Counter({1.0: 552475, 0.0: 461083})
# Epochs : 431, Delta : -26
# Min :
#  Counter({1.0: 552422, 0.0: 461136})
# Epochs : 432, Delta : -53
# Min :
#  Counter({1.0: 552380, 0.0: 461178})
# Epochs : 433, Delta : -42
# Min :
#  Counter({1.0: 552352, 0.0: 461206})
# Epochs : 434, Delta : -28
# Min :
#  Counter({1.0: 552316, 0.0: 461242})
# Epochs : 435, Delta : -36
# Min :
#  Counter({1.0: 552278, 0.0: 461280})
# Epochs : 436, Delta : -38
# Min :
#  Counter({1.0: 552246, 0.0: 461312})
# Epochs : 437, Delta : -32
# Min :
#  Counter({1.0: 552214, 0.0: 461344})
# Epochs : 438, Delta : -32
# Min :
#  Counter({1.0: 552189, 0.0: 461369})
# Epochs : 439, Delta : -25
# Min :
#  Counter({1.0: 552148, 0.0: 461410})
# Epochs : 440, Delta : -41
# Min :
#  Counter({1.0: 552132, 0.0: 461426})
# Epochs : 441, Delta : -16
# Min :
#  Counter({1.0: 552101, 0.0: 461457})
# Epochs : 442, Delta : -31
# Min :
#  Counter({1.0: 552062, 0.0: 461496})
# Epochs : 443, Delta : -39
# Min :
#  Counter({1.0: 552034, 0.0: 461524})
# Epochs : 444, Delta : -28
# Min :
#  Counter({1.0: 551982, 0.0: 461576})
# Epochs : 445, Delta : -52
# Min :
#  Counter({1.0: 551955, 0.0: 461603})
# Epochs : 446, Delta : -27
# Min :
#  Counter({1.0: 551908, 0.0: 461650})
# Epochs : 447, Delta : -47
# Min :
#  Counter({1.0: 551894, 0.0: 461664})
# Epochs : 448, Delta : -14
# Min :
#  Counter({1.0: 551864, 0.0: 461694})
# Epochs : 449, Delta : -30
# Min :
#  Counter({1.0: 551838, 0.0: 461720})
# Epochs : 450, Delta : -26
# Min :
#  Counter({1.0: 551814, 0.0: 461744})
# Epochs : 451, Delta : -24
# Min :
#  Counter({1.0: 551771, 0.0: 461787})
# Epochs : 452, Delta : -43
# Min :
#  Counter({1.0: 551733, 0.0: 461825})
# Epochs : 453, Delta : -38
# Min :
#  Counter({1.0: 551695, 0.0: 461863})
# Epochs : 454, Delta : -38
# Min :
#  Counter({1.0: 551656, 0.0: 461902})
# Epochs : 455, Delta : -39
# Min :
#  Counter({1.0: 551628, 0.0: 461930})
# Epochs : 456, Delta : -28
# Min :
#  Counter({1.0: 551602, 0.0: 461956})
# Epochs : 457, Delta : -26
# Min :
#  Counter({1.0: 551587, 0.0: 461971})
# Epochs : 458, Delta : -15
# Min :
#  Counter({1.0: 551554, 0.0: 462004})
# Epochs : 459, Delta : -33
# Min :
#  Counter({1.0: 551524, 0.0: 462034})
# Epochs : 460, Delta : -30
# Min :
#  Counter({1.0: 551506, 0.0: 462052})
# Epochs : 461, Delta : -18
# Min :
#  Counter({1.0: 551488, 0.0: 462070})
# Epochs : 462, Delta : -18
# Min :
#  Counter({1.0: 551453, 0.0: 462105})
# Epochs : 463, Delta : -35
# Min :
#  Counter({1.0: 551434, 0.0: 462124})
# Epochs : 464, Delta : -19
# Min :
#  Counter({1.0: 551410, 0.0: 462148})
# Epochs : 465, Delta : -24
# Min :
#  Counter({1.0: 551398, 0.0: 462160})
# Epochs : 466, Delta : -12
# Min :
#  Counter({1.0: 551365, 0.0: 462193})
# Epochs : 467, Delta : -33
# Min :
#  Counter({1.0: 551331, 0.0: 462227})
# Epochs : 468, Delta : -34
# Min :
#  Counter({1.0: 551296, 0.0: 462262})
# Epochs : 469, Delta : -35
# Min :
#  Counter({1.0: 551274, 0.0: 462284})
# Epochs : 470, Delta : -22
# Min :
#  Counter({1.0: 551255, 0.0: 462303})
# Epochs : 471, Delta : -19
# Min :
#  Counter({1.0: 551213, 0.0: 462345})
# Epochs : 472, Delta : -42
# Min :
#  Counter({1.0: 551186, 0.0: 462372})
# Epochs : 473, Delta : -27
# Min :
#  Counter({1.0: 551140, 0.0: 462418})
# Epochs : 474, Delta : -46
# Min :
#  Counter({1.0: 551114, 0.0: 462444})
# Epochs : 475, Delta : -26
# Min :
#  Counter({1.0: 551077, 0.0: 462481})
# Epochs : 476, Delta : -37
# Min :
#  Counter({1.0: 551050, 0.0: 462508})
# Epochs : 477, Delta : -27
# Min :
#  Counter({1.0: 551019, 0.0: 462539})
# Epochs : 478, Delta : -31
# Min :
#  Counter({1.0: 550998, 0.0: 462560})
# Epochs : 479, Delta : -21
# Min :
#  Counter({1.0: 550982, 0.0: 462576})
# Epochs : 480, Delta : -16
# Min :
#  Counter({1.0: 550955, 0.0: 462603})
# Epochs : 481, Delta : -27
# Min :
#  Counter({1.0: 550921, 0.0: 462637})
# Epochs : 482, Delta : -34
# Min :
#  Counter({1.0: 550893, 0.0: 462665})
# Epochs : 483, Delta : -28
# Min :
#  Counter({1.0: 550872, 0.0: 462686})
# Epochs : 484, Delta : -21
# Min :
#  Counter({1.0: 550836, 0.0: 462722})
# Epochs : 485, Delta : -36
# Min :
#  Counter({1.0: 550815, 0.0: 462743})
# Epochs : 486, Delta : -21
# Min :
#  Counter({1.0: 550776, 0.0: 462782})
# Epochs : 487, Delta : -39
# Min :
#  Counter({1.0: 550766, 0.0: 462792})
# Epochs : 488, Delta : -10
# Min :
#  Counter({1.0: 550728, 0.0: 462830})
# Epochs : 489, Delta : -38
# Min :
#  Counter({1.0: 550704, 0.0: 462854})
# Epochs : 490, Delta : -24
# Min :
#  Counter({1.0: 550673, 0.0: 462885})
# Epochs : 491, Delta : -31
# Min :
#  Counter({1.0: 550663, 0.0: 462895})
# Epochs : 492, Delta : -10
# Min :
#  Counter({1.0: 550640, 0.0: 462918})
# Epochs : 493, Delta : -23
# Min :
#  Counter({1.0: 550616, 0.0: 462942})
# Epochs : 494, Delta : -24
# Min :
#  Counter({1.0: 550572, 0.0: 462986})
# Epochs : 495, Delta : -44
# Min :
#  Counter({1.0: 550568, 0.0: 462990})
# Epochs : 496, Delta : -4
# Min :
#  Counter({1.0: 550538, 0.0: 463020})
# Epochs : 497, Delta : -30
# Min :
#  Counter({1.0: 550508, 0.0: 463050})
# Epochs : 498, Delta : -30
# Min :
#  Counter({1.0: 550486, 0.0: 463072})
# Epochs : 499, Delta : -22
# Min :
#  Counter({1.0: 550465, 0.0: 463093})
# Epochs : 500, Delta : -21
# Min :
#  Counter({1.0: 550438, 0.0: 463120})
# Epochs : 501, Delta : -27
# Min :
#  Counter({1.0: 550406, 0.0: 463152})
# Epochs : 502, Delta : -32
# Min :
#  Counter({1.0: 550372, 0.0: 463186})
# Epochs : 503, Delta : -34
# Min :
#  Counter({1.0: 550346, 0.0: 463212})
# Epochs : 504, Delta : -26
# Min :
#  Counter({1.0: 550305, 0.0: 463253})
# Epochs : 505, Delta : -41
# Min :
#  Counter({1.0: 550279, 0.0: 463279})
# Epochs : 506, Delta : -26
# Min :
#  Counter({1.0: 550258, 0.0: 463300})
# Epochs : 507, Delta : -21
# Min :
#  Counter({1.0: 550255, 0.0: 463303})
# Epochs : 508, Delta : -3
# Min :
#  Counter({1.0: 550235, 0.0: 463323})
# Epochs : 509, Delta : -20
# Min :
#  Counter({1.0: 550236, 0.0: 463322})
# Epochs : 510, Delta : 1
# Min :
#  Counter({1.0: 550214, 0.0: 463344})
# Epochs : 511, Delta : -22
# Min :
#  Counter({1.0: 550175, 0.0: 463383})
# Epochs : 512, Delta : -39
# Min :
#  Counter({1.0: 550141, 0.0: 463417})
# Epochs : 513, Delta : -34
# Min :
#  Counter({1.0: 550111, 0.0: 463447})
# Epochs : 514, Delta : -30
# Min :
#  Counter({1.0: 550076, 0.0: 463482})
# Epochs : 515, Delta : -35
# Min :
#  Counter({1.0: 550050, 0.0: 463508})
# Epochs : 516, Delta : -26
# Min :
#  Counter({1.0: 550020, 0.0: 463538})
# Epochs : 517, Delta : -30
# Min :
#  Counter({1.0: 549979, 0.0: 463579})
# Epochs : 518, Delta : -41
# Min :
#  Counter({1.0: 549968, 0.0: 463590})
# Epochs : 519, Delta : -11
# Min :
#  Counter({1.0: 549947, 0.0: 463611})
# Epochs : 520, Delta : -21
# Min :
#  Counter({1.0: 549926, 0.0: 463632})
# Epochs : 521, Delta : -21
# Min :
#  Counter({1.0: 549905, 0.0: 463653})
# Epochs : 522, Delta : -21
# Min :
#  Counter({1.0: 549869, 0.0: 463689})
# Epochs : 523, Delta : -36
# Min :
#  Counter({1.0: 549850, 0.0: 463708})
# Epochs : 524, Delta : -19
# Min :
#  Counter({1.0: 549824, 0.0: 463734})
# Epochs : 525, Delta : -26
# Min :
#  Counter({1.0: 549790, 0.0: 463768})
# Epochs : 526, Delta : -34
# Min :
#  Counter({1.0: 549763, 0.0: 463795})
# Epochs : 527, Delta : -27
# Min :
#  Counter({1.0: 549733, 0.0: 463825})
# Epochs : 528, Delta : -30
# Min :
#  Counter({1.0: 549715, 0.0: 463843})
# Epochs : 529, Delta : -18
# Min :
#  Counter({1.0: 549684, 0.0: 463874})
# Epochs : 530, Delta : -31
# Min :
#  Counter({1.0: 549656, 0.0: 463902})
# Epochs : 531, Delta : -28
# Min :
#  Counter({1.0: 549632, 0.0: 463926})
# Epochs : 532, Delta : -24
# Min :
#  Counter({1.0: 549602, 0.0: 463956})
# Epochs : 533, Delta : -30
# Min :
#  Counter({1.0: 549568, 0.0: 463990})
# Epochs : 534, Delta : -34
# Min :
#  Counter({1.0: 549545, 0.0: 464013})
# Epochs : 535, Delta : -23
# Min :
#  Counter({1.0: 549520, 0.0: 464038})
# Epochs : 536, Delta : -25
# Min :
#  Counter({1.0: 549505, 0.0: 464053})
# Epochs : 537, Delta : -15
# Min :
#  Counter({1.0: 549484, 0.0: 464074})
# Epochs : 538, Delta : -21
# Min :
#  Counter({1.0: 549461, 0.0: 464097})
# Epochs : 539, Delta : -23
# Min :
#  Counter({1.0: 549439, 0.0: 464119})
# Epochs : 540, Delta : -22
# Min :
#  Counter({1.0: 549428, 0.0: 464130})
# Epochs : 541, Delta : -11
# Min :
#  Counter({1.0: 549399, 0.0: 464159})
# Epochs : 542, Delta : -29
# Min :
#  Counter({1.0: 549367, 0.0: 464191})
# Epochs : 543, Delta : -32
# Min :
#  Counter({1.0: 549343, 0.0: 464215})
# Epochs : 544, Delta : -24
# Min :
#  Counter({1.0: 549327, 0.0: 464231})
# Epochs : 545, Delta : -16
# Min :
#  Counter({1.0: 549305, 0.0: 464253})
# Epochs : 546, Delta : -22
# Min :
#  Counter({1.0: 549283, 0.0: 464275})
# Epochs : 547, Delta : -22
# Min :
#  Counter({1.0: 549267, 0.0: 464291})
# Epochs : 548, Delta : -16
# Min :
#  Counter({1.0: 549234, 0.0: 464324})
# Epochs : 549, Delta : -33
# Min :
#  Counter({1.0: 549217, 0.0: 464341})
# Epochs : 550, Delta : -17
# Min :
#  Counter({1.0: 549194, 0.0: 464364})
# Epochs : 551, Delta : -23
# Min :
#  Counter({1.0: 549171, 0.0: 464387})
# Epochs : 552, Delta : -23
# Min :
#  Counter({1.0: 549144, 0.0: 464414})
# Epochs : 553, Delta : -27
# Min :
#  Counter({1.0: 549107, 0.0: 464451})
# Epochs : 554, Delta : -37
# Min :
#  Counter({1.0: 549095, 0.0: 464463})
# Epochs : 555, Delta : -12
# Min :
#  Counter({1.0: 549085, 0.0: 464473})
# Epochs : 556, Delta : -10
# Min :
#  Counter({1.0: 549051, 0.0: 464507})
# Epochs : 557, Delta : -34
# Min :
#  Counter({1.0: 549015, 0.0: 464543})
# Epochs : 558, Delta : -36
# Min :
#  Counter({1.0: 548997, 0.0: 464561})
# Epochs : 559, Delta : -18
# Min :
#  Counter({1.0: 548973, 0.0: 464585})
# Epochs : 560, Delta : -24
# Min :
#  Counter({1.0: 548944, 0.0: 464614})
# Epochs : 561, Delta : -29
# Min :
#  Counter({1.0: 548912, 0.0: 464646})
# Epochs : 562, Delta : -32
# Min :
#  Counter({1.0: 548896, 0.0: 464662})
# Epochs : 563, Delta : -16
# Min :
#  Counter({1.0: 548876, 0.0: 464682})
# Epochs : 564, Delta : -20
# Min :
#  Counter({1.0: 548854, 0.0: 464704})
# Epochs : 565, Delta : -22
# Min :
#  Counter({1.0: 548818, 0.0: 464740})
# Epochs : 566, Delta : -36
# Min :
#  Counter({1.0: 548786, 0.0: 464772})
# Epochs : 567, Delta : -32
# Min :
#  Counter({1.0: 548765, 0.0: 464793})
# Epochs : 568, Delta : -21
# Min :
#  Counter({1.0: 548745, 0.0: 464813})
# Epochs : 569, Delta : -20
# Min :
#  Counter({1.0: 548729, 0.0: 464829})
# Epochs : 570, Delta : -16
# Min :
#  Counter({1.0: 548710, 0.0: 464848})
# Epochs : 571, Delta : -19
# Min :
#  Counter({1.0: 548699, 0.0: 464859})
# Epochs : 572, Delta : -11
# Min :
#  Counter({1.0: 548675, 0.0: 464883})
# Epochs : 573, Delta : -24
# Min :
#  Counter({1.0: 548645, 0.0: 464913})
# Epochs : 574, Delta : -30
# Min :
#  Counter({1.0: 548634, 0.0: 464924})
# Epochs : 575, Delta : -11
# Min :
#  Counter({1.0: 548607, 0.0: 464951})
# Epochs : 576, Delta : -27
# Min :
#  Counter({1.0: 548601, 0.0: 464957})
# Epochs : 577, Delta : -6
# Min :
#  Counter({1.0: 548578, 0.0: 464980})
# Epochs : 578, Delta : -23
# Min :
#  Counter({1.0: 548553, 0.0: 465005})
# Epochs : 579, Delta : -25
# Min :
#  Counter({1.0: 548547, 0.0: 465011})
# Epochs : 580, Delta : -6
# Min :
#  Counter({1.0: 548534, 0.0: 465024})
# Epochs : 581, Delta : -13
# Min :
#  Counter({1.0: 548516, 0.0: 465042})
# Epochs : 582, Delta : -18
# Min :
#  Counter({1.0: 548499, 0.0: 465059})
# Epochs : 583, Delta : -17
# Min :
#  Counter({1.0: 548460, 0.0: 465098})
# Epochs : 584, Delta : -39
# Min :
#  Counter({1.0: 548435, 0.0: 465123})
# Epochs : 585, Delta : -25
# Min :
#  Counter({1.0: 548417, 0.0: 465141})
# Epochs : 586, Delta : -18
# Min :
#  Counter({1.0: 548395, 0.0: 465163})
# Epochs : 587, Delta : -22
# Min :
#  Counter({1.0: 548364, 0.0: 465194})
# Epochs : 588, Delta : -31
# Min :
#  Counter({1.0: 548352, 0.0: 465206})
# Epochs : 589, Delta : -12
# Min :
#  Counter({1.0: 548335, 0.0: 465223})
# Epochs : 590, Delta : -17
# Min :
#  Counter({1.0: 548308, 0.0: 465250})
# Epochs : 591, Delta : -27
# Min :
#  Counter({1.0: 548289, 0.0: 465269})
# Epochs : 592, Delta : -19
# Min :
#  Counter({1.0: 548264, 0.0: 465294})
# Epochs : 593, Delta : -25
# Min :
#  Counter({1.0: 548228, 0.0: 465330})
# Epochs : 594, Delta : -36
# Min :
#  Counter({1.0: 548189, 0.0: 465369})
# Epochs : 595, Delta : -39
# Min :
#  Counter({1.0: 548179, 0.0: 465379})
# Epochs : 596, Delta : -10
# Min :
#  Counter({1.0: 548160, 0.0: 465398})
# Epochs : 597, Delta : -19
# Min :
#  Counter({1.0: 548141, 0.0: 465417})
# Epochs : 598, Delta : -19
# Min :
#  Counter({1.0: 548119, 0.0: 465439})
# Epochs : 599, Delta : -22
# Min :
#  Counter({1.0: 548093, 0.0: 465465})
# Epochs : 600, Delta : -26
# Min :
#  Counter({1.0: 548077, 0.0: 465481})
# Epochs : 601, Delta : -16
# Min :
#  Counter({1.0: 548068, 0.0: 465490})
# Epochs : 602, Delta : -9
# Min :
#  Counter({1.0: 548049, 0.0: 465509})
# Epochs : 603, Delta : -19
# Min :
#  Counter({1.0: 548035, 0.0: 465523})
# Epochs : 604, Delta : -14
# Min :
#  Counter({1.0: 548021, 0.0: 465537})
# Epochs : 605, Delta : -14
# Min :
#  Counter({1.0: 548005, 0.0: 465553})
# Epochs : 606, Delta : -16
# Min :
#  Counter({1.0: 548001, 0.0: 465557})
# Epochs : 607, Delta : -4
# Min :
#  Counter({1.0: 547983, 0.0: 465575})
# Epochs : 608, Delta : -18
# Min :
#  Counter({1.0: 547960, 0.0: 465598})
# Epochs : 609, Delta : -23
# Min :
#  Counter({1.0: 547952, 0.0: 465606})
# Epochs : 610, Delta : -8
# Min :
#  Counter({1.0: 547920, 0.0: 465638})
# Epochs : 611, Delta : -32
# Min :
#  Counter({1.0: 547900, 0.0: 465658})
# Epochs : 612, Delta : -20
# Min :
#  Counter({1.0: 547888, 0.0: 465670})
# Epochs : 613, Delta : -12
# Min :
#  Counter({1.0: 547861, 0.0: 465697})
# Epochs : 614, Delta : -27
# Min :
#  Counter({1.0: 547828, 0.0: 465730})
# Epochs : 615, Delta : -33
# Min :
#  Counter({1.0: 547817, 0.0: 465741})
# Epochs : 616, Delta : -11
# Min :
#  Counter({1.0: 547787, 0.0: 465771})
# Epochs : 617, Delta : -30
# Min :
#  Counter({1.0: 547749, 0.0: 465809})
# Epochs : 618, Delta : -38
# Min :
#  Counter({1.0: 547738, 0.0: 465820})
# Epochs : 619, Delta : -11
# Min :
#  Counter({1.0: 547718, 0.0: 465840})
# Epochs : 620, Delta : -20
# Min :
#  Counter({1.0: 547677, 0.0: 465881})
# Epochs : 621, Delta : -41
# Min :
#  Counter({1.0: 547657, 0.0: 465901})
# Epochs : 622, Delta : -20
# Min :
#  Counter({1.0: 547638, 0.0: 465920})
# Epochs : 623, Delta : -19
# Min :
#  Counter({1.0: 547618, 0.0: 465940})
# Epochs : 624, Delta : -20
# Min :
#  Counter({1.0: 547609, 0.0: 465949})
# Epochs : 625, Delta : -9
# Min :
#  Counter({1.0: 547591, 0.0: 465967})
# Epochs : 626, Delta : -18
# Min :
#  Counter({1.0: 547573, 0.0: 465985})
# Epochs : 627, Delta : -18
# Min :
#  Counter({1.0: 547548, 0.0: 466010})
# Epochs : 628, Delta : -25
# Min :
#  Counter({1.0: 547536, 0.0: 466022})
# Epochs : 629, Delta : -12
# Min :
#  Counter({1.0: 547509, 0.0: 466049})
# Epochs : 630, Delta : -27
# Min :
#  Counter({1.0: 547499, 0.0: 466059})
# Epochs : 631, Delta : -10
# Min :
#  Counter({1.0: 547466, 0.0: 466092})
# Epochs : 632, Delta : -33
# Min :
#  Counter({1.0: 547448, 0.0: 466110})
# Epochs : 633, Delta : -18
# Min :
#  Counter({1.0: 547427, 0.0: 466131})
# Epochs : 634, Delta : -21
# Min :
#  Counter({1.0: 547401, 0.0: 466157})
# Epochs : 635, Delta : -26
# Min :
#  Counter({1.0: 547387, 0.0: 466171})
# Epochs : 636, Delta : -14
# Min :
#  Counter({1.0: 547380, 0.0: 466178})
# Epochs : 637, Delta : -7
# Min :
#  Counter({1.0: 547354, 0.0: 466204})
# Epochs : 638, Delta : -26
# Min :
#  Counter({1.0: 547324, 0.0: 466234})
# Epochs : 639, Delta : -30
# Min :
#  Counter({1.0: 547317, 0.0: 466241})
# Epochs : 640, Delta : -7
# Min :
#  Counter({1.0: 547301, 0.0: 466257})
# Epochs : 641, Delta : -16
# Min :
#  Counter({1.0: 547289, 0.0: 466269})
# Epochs : 642, Delta : -12
# Min :
#  Counter({1.0: 547262, 0.0: 466296})
# Epochs : 643, Delta : -27
# Min :
#  Counter({1.0: 547227, 0.0: 466331})
# Epochs : 644, Delta : -35
# Min :
#  Counter({1.0: 547211, 0.0: 466347})
# Epochs : 645, Delta : -16
# Min :
#  Counter({1.0: 547183, 0.0: 466375})
# Epochs : 646, Delta : -28
# Min :
#  Counter({1.0: 547164, 0.0: 466394})
# Epochs : 647, Delta : -19
# Min :
#  Counter({1.0: 547129, 0.0: 466429})
# Epochs : 648, Delta : -35
# Min :
#  Counter({1.0: 547108, 0.0: 466450})
# Epochs : 649, Delta : -21
# Min :
#  Counter({1.0: 547092, 0.0: 466466})
# Epochs : 650, Delta : -16
# Min :
#  Counter({1.0: 547071, 0.0: 466487})
# Epochs : 651, Delta : -21
# Min :
#  Counter({1.0: 547053, 0.0: 466505})
# Epochs : 652, Delta : -18
# Min :
#  Counter({1.0: 547033, 0.0: 466525})
# Epochs : 653, Delta : -20
# Min :
#  Counter({1.0: 547011, 0.0: 466547})
# Epochs : 654, Delta : -22
# Min :
#  Counter({1.0: 547001, 0.0: 466557})
# Epochs : 655, Delta : -10
# Min :
#  Counter({1.0: 546966, 0.0: 466592})
# Epochs : 656, Delta : -35
# Min :
#  Counter({1.0: 546932, 0.0: 466626})
# Epochs : 657, Delta : -34
# Min :
#  Counter({1.0: 546925, 0.0: 466633})
# Epochs : 658, Delta : -7
# Min :
#  Counter({1.0: 546901, 0.0: 466657})
# Epochs : 659, Delta : -24
# Min :
#  Counter({1.0: 546872, 0.0: 466686})
# Epochs : 660, Delta : -29
# Min :
#  Counter({1.0: 546850, 0.0: 466708})
# Epochs : 661, Delta : -22
# Min :
#  Counter({1.0: 546827, 0.0: 466731})
# Epochs : 662, Delta : -23
# Min :
#  Counter({1.0: 546810, 0.0: 466748})
# Epochs : 663, Delta : -17
# Min :
#  Counter({1.0: 546802, 0.0: 466756})
# Epochs : 664, Delta : -8
# Min :
#  Counter({1.0: 546788, 0.0: 466770})
# Epochs : 665, Delta : -14
# Min :
#  Counter({1.0: 546774, 0.0: 466784})
# Epochs : 666, Delta : -14
# Min :
#  Counter({1.0: 546753, 0.0: 466805})
# Epochs : 667, Delta : -21
# Min :
#  Counter({1.0: 546743, 0.0: 466815})
# Epochs : 668, Delta : -10
# Min :
#  Counter({1.0: 546726, 0.0: 466832})
# Epochs : 669, Delta : -17
# Min :
#  Counter({1.0: 546710, 0.0: 466848})
# Epochs : 670, Delta : -16
# Min :
#  Counter({1.0: 546689, 0.0: 466869})
# Epochs : 671, Delta : -21
# Min :
#  Counter({1.0: 546677, 0.0: 466881})
# Epochs : 672, Delta : -12
# Min :
#  Counter({1.0: 546680, 0.0: 466878})
# Epochs : 673, Delta : 3
# Min :
#  Counter({1.0: 546664, 0.0: 466894})
# Epochs : 674, Delta : -16
# Min :
#  Counter({1.0: 546643, 0.0: 466915})
# Epochs : 675, Delta : -21
# Min :
#  Counter({1.0: 546625, 0.0: 466933})
# Epochs : 676, Delta : -18
# Min :
#  Counter({1.0: 546604, 0.0: 466954})
# Epochs : 677, Delta : -21
# Min :
#  Counter({1.0: 546563, 0.0: 466995})
# Epochs : 678, Delta : -41
# Min :
#  Counter({1.0: 546543, 0.0: 467015})
# Epochs : 679, Delta : -20
# Min :
#  Counter({1.0: 546519, 0.0: 467039})
# Epochs : 680, Delta : -24
# Min :
#  Counter({1.0: 546500, 0.0: 467058})
# Epochs : 681, Delta : -19
# Min :
#  Counter({1.0: 546489, 0.0: 467069})
# Epochs : 682, Delta : -11
# Min :
#  Counter({1.0: 546479, 0.0: 467079})
# Epochs : 683, Delta : -10
# Min :
#  Counter({1.0: 546459, 0.0: 467099})
# Epochs : 684, Delta : -20
# Min :
#  Counter({1.0: 546434, 0.0: 467124})
# Epochs : 685, Delta : -25
# Min :
#  Counter({1.0: 546417, 0.0: 467141})
# Epochs : 686, Delta : -17
# Min :
#  Counter({1.0: 546401, 0.0: 467157})
# Epochs : 687, Delta : -16
# Min :
#  Counter({1.0: 546382, 0.0: 467176})
# Epochs : 688, Delta : -19
# Min :
#  Counter({1.0: 546361, 0.0: 467197})
# Epochs : 689, Delta : -21
# Min :
#  Counter({1.0: 546356, 0.0: 467202})
# Epochs : 690, Delta : -5
# Min :
#  Counter({1.0: 546335, 0.0: 467223})
# Epochs : 691, Delta : -21
# Min :
#  Counter({1.0: 546320, 0.0: 467238})
# Epochs : 692, Delta : -15
# Min :
#  Counter({1.0: 546304, 0.0: 467254})
# Epochs : 693, Delta : -16
# Min :
#  Counter({1.0: 546296, 0.0: 467262})
# Epochs : 694, Delta : -8
# Min :
#  Counter({1.0: 546277, 0.0: 467281})
# Epochs : 695, Delta : -19
# Min :
#  Counter({1.0: 546260, 0.0: 467298})
# Epochs : 696, Delta : -17
# Min :
#  Counter({1.0: 546247, 0.0: 467311})
# Epochs : 697, Delta : -13
# Min :
#  Counter({1.0: 546233, 0.0: 467325})
# Epochs : 698, Delta : -14
# Min :
#  Counter({1.0: 546201, 0.0: 467357})
# Epochs : 699, Delta : -32
# Min :
#  Counter({1.0: 546191, 0.0: 467367})
# Epochs : 700, Delta : -10
# Min :
#  Counter({1.0: 546160, 0.0: 467398})
# Epochs : 701, Delta : -31
# Min :
#  Counter({1.0: 546135, 0.0: 467423})
# Epochs : 702, Delta : -25
# Min :
#  Counter({1.0: 546116, 0.0: 467442})
# Epochs : 703, Delta : -19
# Min :
#  Counter({1.0: 546094, 0.0: 467464})
# Epochs : 704, Delta : -22
# Min :
#  Counter({1.0: 546072, 0.0: 467486})
# Epochs : 705, Delta : -22
# Min :
#  Counter({1.0: 546053, 0.0: 467505})
# Epochs : 706, Delta : -19
# Min :
#  Counter({1.0: 546041, 0.0: 467517})
# Epochs : 707, Delta : -12
# Min :
#  Counter({1.0: 546021, 0.0: 467537})
# Epochs : 708, Delta : -20
# Min :
#  Counter({1.0: 545985, 0.0: 467573})
# Epochs : 709, Delta : -36
# Min :
#  Counter({1.0: 545960, 0.0: 467598})
# Epochs : 710, Delta : -25
# Min :
#  Counter({1.0: 545937, 0.0: 467621})
# Epochs : 711, Delta : -23
# Min :
#  Counter({1.0: 545918, 0.0: 467640})
# Epochs : 712, Delta : -19
# Min :
#  Counter({1.0: 545898, 0.0: 467660})
# Epochs : 713, Delta : -20
# Min :
#  Counter({1.0: 545886, 0.0: 467672})
# Epochs : 714, Delta : -12
# Min :
#  Counter({1.0: 545871, 0.0: 467687})
# Epochs : 715, Delta : -15
# Min :
#  Counter({1.0: 545860, 0.0: 467698})
# Epochs : 716, Delta : -11
# Min :
#  Counter({1.0: 545841, 0.0: 467717})
# Epochs : 717, Delta : -19
# Min :
#  Counter({1.0: 545833, 0.0: 467725})
# Epochs : 718, Delta : -8
# Min :
#  Counter({1.0: 545820, 0.0: 467738})
# Epochs : 719, Delta : -13
# Min :
#  Counter({1.0: 545796, 0.0: 467762})
# Epochs : 720, Delta : -24
# Min :
#  Counter({1.0: 545792, 0.0: 467766})
# Epochs : 721, Delta : -4
# Min :
#  Counter({1.0: 545772, 0.0: 467786})
# Epochs : 722, Delta : -20
# Min :
#  Counter({1.0: 545752, 0.0: 467806})
# Epochs : 723, Delta : -20
# Min :
#  Counter({1.0: 545732, 0.0: 467826})
# Epochs : 724, Delta : -20
# Min :
#  Counter({1.0: 545717, 0.0: 467841})
# Epochs : 725, Delta : -15
# Min :
#  Counter({1.0: 545700, 0.0: 467858})
# Epochs : 726, Delta : -17
# Min :
#  Counter({1.0: 545685, 0.0: 467873})
# Epochs : 727, Delta : -15
# Min :
#  Counter({1.0: 545686, 0.0: 467872})
# Epochs : 728, Delta : 1
# Min :
#  Counter({1.0: 545645, 0.0: 467913})
# Epochs : 729, Delta : -41
# Min :
#  Counter({1.0: 545634, 0.0: 467924})
# Epochs : 730, Delta : -11
# Min :
#  Counter({1.0: 545618, 0.0: 467940})
# Epochs : 731, Delta : -16
# Min :
#  Counter({1.0: 545605, 0.0: 467953})
# Epochs : 732, Delta : -13
# Min :
#  Counter({1.0: 545589, 0.0: 467969})
# Epochs : 733, Delta : -16
# Min :
#  Counter({1.0: 545581, 0.0: 467977})
# Epochs : 734, Delta : -8
# Min :
#  Counter({1.0: 545577, 0.0: 467981})
# Epochs : 735, Delta : -4
# Min :
#  Counter({1.0: 545562, 0.0: 467996})
# Epochs : 736, Delta : -15
# Min :
#  Counter({1.0: 545543, 0.0: 468015})
# Epochs : 737, Delta : -19
# Min :
#  Counter({1.0: 545524, 0.0: 468034})
# Epochs : 738, Delta : -19
# Min :
#  Counter({1.0: 545512, 0.0: 468046})
# Epochs : 739, Delta : -12
# Min :
#  Counter({1.0: 545500, 0.0: 468058})
# Epochs : 740, Delta : -12
# Min :
#  Counter({1.0: 545471, 0.0: 468087})
# Epochs : 741, Delta : -29
# Min :
#  Counter({1.0: 545443, 0.0: 468115})
# Epochs : 742, Delta : -28
# Min :
#  Counter({1.0: 545415, 0.0: 468143})
# Epochs : 743, Delta : -28
# Min :
#  Counter({1.0: 545405, 0.0: 468153})
# Epochs : 744, Delta : -10
# Min :
#  Counter({1.0: 545395, 0.0: 468163})
# Epochs : 745, Delta : -10
# Min :
#  Counter({1.0: 545380, 0.0: 468178})
# Epochs : 746, Delta : -15
# Min :
#  Counter({1.0: 545370, 0.0: 468188})
# Epochs : 747, Delta : -10
# Min :
#  Counter({1.0: 545342, 0.0: 468216})
# Epochs : 748, Delta : -28
# Min :
#  Counter({1.0: 545324, 0.0: 468234})
# Epochs : 749, Delta : -18
# Min :
#  Counter({1.0: 545322, 0.0: 468236})
# Epochs : 750, Delta : -2
# Min :
#  Counter({1.0: 545313, 0.0: 468245})
# Epochs : 751, Delta : -9
# Min :
#  Counter({1.0: 545309, 0.0: 468249})
# Epochs : 752, Delta : -4
# Min :
#  Counter({1.0: 545289, 0.0: 468269})
# Epochs : 753, Delta : -20
# Min :
#  Counter({1.0: 545272, 0.0: 468286})
# Epochs : 754, Delta : -17
# Min :
#  Counter({1.0: 545261, 0.0: 468297})
# Epochs : 755, Delta : -11
# Min :
#  Counter({1.0: 545254, 0.0: 468304})
# Epochs : 756, Delta : -7
# Min :
#  Counter({1.0: 545251, 0.0: 468307})
# Epochs : 757, Delta : -3
# Min :
#  Counter({1.0: 545234, 0.0: 468324})
# Epochs : 758, Delta : -17
# Min :
#  Counter({1.0: 545218, 0.0: 468340})
# Epochs : 759, Delta : -16
# Min :
#  Counter({1.0: 545200, 0.0: 468358})
# Epochs : 760, Delta : -18
# Min :
#  Counter({1.0: 545172, 0.0: 468386})
# Epochs : 761, Delta : -28
# Min :
#  Counter({1.0: 545150, 0.0: 468408})
# Epochs : 762, Delta : -22
# Min :
#  Counter({1.0: 545122, 0.0: 468436})
# Epochs : 763, Delta : -28
# Min :
#  Counter({1.0: 545111, 0.0: 468447})
# Epochs : 764, Delta : -11
# Min :
#  Counter({1.0: 545103, 0.0: 468455})
# Epochs : 765, Delta : -8
# Min :
#  Counter({1.0: 545092, 0.0: 468466})
# Epochs : 766, Delta : -11
# Min :
#  Counter({1.0: 545077, 0.0: 468481})
# Epochs : 767, Delta : -15
# Min :
#  Counter({1.0: 545057, 0.0: 468501})
# Epochs : 768, Delta : -20
# Min :
#  Counter({1.0: 545041, 0.0: 468517})
# Epochs : 769, Delta : -16
# Min :
#  Counter({1.0: 545035, 0.0: 468523})
# Epochs : 770, Delta : -6
# Min :
#  Counter({1.0: 545026, 0.0: 468532})
# Epochs : 771, Delta : -9
# Min :
#  Counter({1.0: 545025, 0.0: 468533})
# Epochs : 772, Delta : -1
# Min :
#  Counter({1.0: 545007, 0.0: 468551})
# Epochs : 773, Delta : -18
# Min :
#  Counter({1.0: 544996, 0.0: 468562})
# Epochs : 774, Delta : -11
# Min :
#  Counter({1.0: 544979, 0.0: 468579})
# Epochs : 775, Delta : -17
# Min :
#  Counter({1.0: 544976, 0.0: 468582})
# Epochs : 776, Delta : -3
# Min :
#  Counter({1.0: 544965, 0.0: 468593})
# Epochs : 777, Delta : -11
# Min :
#  Counter({1.0: 544960, 0.0: 468598})
# Epochs : 778, Delta : -5
# Min :
#  Counter({1.0: 544937, 0.0: 468621})
# Epochs : 779, Delta : -23
# Min :
#  Counter({1.0: 544908, 0.0: 468650})
# Epochs : 780, Delta : -29
# Min :
#  Counter({1.0: 544888, 0.0: 468670})
# Epochs : 781, Delta : -20
# Min :
#  Counter({1.0: 544876, 0.0: 468682})
# Epochs : 782, Delta : -12
# Min :
#  Counter({1.0: 544865, 0.0: 468693})
# Epochs : 783, Delta : -11
# Min :
#  Counter({1.0: 544852, 0.0: 468706})
# Epochs : 784, Delta : -13
# Min :
#  Counter({1.0: 544838, 0.0: 468720})
# Epochs : 785, Delta : -14
# Min :
#  Counter({1.0: 544818, 0.0: 468740})
# Epochs : 786, Delta : -20
# Min :
#  Counter({1.0: 544803, 0.0: 468755})
# Epochs : 787, Delta : -15
# Min :
#  Counter({1.0: 544788, 0.0: 468770})
# Epochs : 788, Delta : -15
# Min :
#  Counter({1.0: 544769, 0.0: 468789})
# Epochs : 789, Delta : -19
# Min :
#  Counter({1.0: 544757, 0.0: 468801})
# Epochs : 790, Delta : -12
# Min :
#  Counter({1.0: 544730, 0.0: 468828})
# Epochs : 791, Delta : -27
# Min :
#  Counter({1.0: 544714, 0.0: 468844})
# Epochs : 792, Delta : -16
# Min :
#  Counter({1.0: 544709, 0.0: 468849})
# Epochs : 793, Delta : -5
# Min :
#  Counter({1.0: 544689, 0.0: 468869})
# Epochs : 794, Delta : -20
# Min :
#  Counter({1.0: 544686, 0.0: 468872})
# Epochs : 795, Delta : -3
# Min :
#  Counter({1.0: 544658, 0.0: 468900})
# Epochs : 796, Delta : -28
# Min :
#  Counter({1.0: 544640, 0.0: 468918})
# Epochs : 797, Delta : -18
# Min :
#  Counter({1.0: 544627, 0.0: 468931})
# Epochs : 798, Delta : -13
# Min :
#  Counter({1.0: 544614, 0.0: 468944})
# Epochs : 799, Delta : -13
# Min :
#  Counter({1.0: 544601, 0.0: 468957})
# Epochs : 800, Delta : -13
# Min :
#  Counter({1.0: 544607, 0.0: 468951})
# Epochs : 801, Delta : 6
# Min :
#  Counter({1.0: 544589, 0.0: 468969})
# Epochs : 802, Delta : -18
# Min :
#  Counter({1.0: 544559, 0.0: 468999})
# Epochs : 803, Delta : -30
# Min :
#  Counter({1.0: 544543, 0.0: 469015})
# Epochs : 804, Delta : -16
# Min :
#  Counter({1.0: 544528, 0.0: 469030})
# Epochs : 805, Delta : -15
# Min :
#  Counter({1.0: 544515, 0.0: 469043})
# Epochs : 806, Delta : -13
# Min :
#  Counter({1.0: 544507, 0.0: 469051})
# Epochs : 807, Delta : -8
# Min :
#  Counter({1.0: 544508, 0.0: 469050})
# Epochs : 808, Delta : 1
# Min :
#  Counter({1.0: 544483, 0.0: 469075})
# Epochs : 809, Delta : -25
# Min :
#  Counter({1.0: 544473, 0.0: 469085})
# Epochs : 810, Delta : -10
# Min :
#  Counter({1.0: 544462, 0.0: 469096})
# Epochs : 811, Delta : -11
# Min :
#  Counter({1.0: 544454, 0.0: 469104})
# Epochs : 812, Delta : -8
# Min :
#  Counter({1.0: 544446, 0.0: 469112})
# Epochs : 813, Delta : -8
# Min :
#  Counter({1.0: 544435, 0.0: 469123})
# Epochs : 814, Delta : -11
# Min :
#  Counter({1.0: 544420, 0.0: 469138})
# Epochs : 815, Delta : -15
# Min :
#  Counter({1.0: 544414, 0.0: 469144})
# Epochs : 816, Delta : -6
# Min :
#  Counter({1.0: 544393, 0.0: 469165})
# Epochs : 817, Delta : -21
# Min :
#  Counter({1.0: 544373, 0.0: 469185})
# Epochs : 818, Delta : -20
# Min :
#  Counter({1.0: 544359, 0.0: 469199})
# Epochs : 819, Delta : -14
# Min :
#  Counter({1.0: 544338, 0.0: 469220})
# Epochs : 820, Delta : -21
# Min :
#  Counter({1.0: 544327, 0.0: 469231})
# Epochs : 821, Delta : -11
# Min :
#  Counter({1.0: 544324, 0.0: 469234})
# Epochs : 822, Delta : -3
# Min :
#  Counter({1.0: 544301, 0.0: 469257})
# Epochs : 823, Delta : -23
# Min :
#  Counter({1.0: 544282, 0.0: 469276})
# Epochs : 824, Delta : -19
# Min :
#  Counter({1.0: 544278, 0.0: 469280})
# Epochs : 825, Delta : -4
# Min :
#  Counter({1.0: 544267, 0.0: 469291})
# Epochs : 826, Delta : -11
# Min :
#  Counter({1.0: 544260, 0.0: 469298})
# Epochs : 827, Delta : -7
# Min :
#  Counter({1.0: 544247, 0.0: 469311})
# Epochs : 828, Delta : -13
# Min :
#  Counter({1.0: 544225, 0.0: 469333})
# Epochs : 829, Delta : -22
# Min :
#  Counter({1.0: 544209, 0.0: 469349})
# Epochs : 830, Delta : -16
# Min :
#  Counter({1.0: 544194, 0.0: 469364})
# Epochs : 831, Delta : -15
# Min :
#  Counter({1.0: 544182, 0.0: 469376})
# Epochs : 832, Delta : -12
# Min :
#  Counter({1.0: 544181, 0.0: 469377})
# Epochs : 833, Delta : -1
# Min :
#  Counter({1.0: 544167, 0.0: 469391})
# Epochs : 834, Delta : -14
# Min :
#  Counter({1.0: 544151, 0.0: 469407})
# Epochs : 835, Delta : -16
# Min :
#  Counter({1.0: 544136, 0.0: 469422})
# Epochs : 836, Delta : -15
# Min :
#  Counter({1.0: 544117, 0.0: 469441})
# Epochs : 837, Delta : -19
# Min :
#  Counter({1.0: 544111, 0.0: 469447})
# Epochs : 838, Delta : -6
# Min :
#  Counter({1.0: 544109, 0.0: 469449})
# Epochs : 839, Delta : -2
# Min :
#  Counter({1.0: 544097, 0.0: 469461})
# Epochs : 840, Delta : -12
# Min :
#  Counter({1.0: 544083, 0.0: 469475})
# Epochs : 841, Delta : -14
# Min :
#  Counter({1.0: 544075, 0.0: 469483})
# Epochs : 842, Delta : -8
# Min :
#  Counter({1.0: 544047, 0.0: 469511})
# Epochs : 843, Delta : -28
# Min :
#  Counter({1.0: 544033, 0.0: 469525})
# Epochs : 844, Delta : -14
# Min :
#  Counter({1.0: 544023, 0.0: 469535})
# Epochs : 845, Delta : -10
# Min :
#  Counter({1.0: 544007, 0.0: 469551})
# Epochs : 846, Delta : -16
# Min :
#  Counter({1.0: 543982, 0.0: 469576})
# Epochs : 847, Delta : -25
# Min :
#  Counter({1.0: 543964, 0.0: 469594})
# Epochs : 848, Delta : -18
# Min :
#  Counter({1.0: 543943, 0.0: 469615})
# Epochs : 849, Delta : -21
# Min :
#  Counter({1.0: 543937, 0.0: 469621})
# Epochs : 850, Delta : -6
# Min :
#  Counter({1.0: 543923, 0.0: 469635})
# Epochs : 851, Delta : -14
# Min :
#  Counter({1.0: 543916, 0.0: 469642})
# Epochs : 852, Delta : -7
# Min :
#  Counter({1.0: 543916, 0.0: 469642})

# %%
specSheet = [{'k':2, 'n':5},
             {'k':3, 'n':5},
             {'k':4, 'n':5},
             {'k':5, 'n':5},
             {'k':6, 'n':5},
             {'k':7, 'n':5},
            {'k':8, 'n':5}]
for s in specSheet:
    for i in range(s['n']):
        name = f"no{i}_k{s['k']}_n1M_range"
        clear()
        genData(s['k'],5)
        epoch = 1
        deltaBool = [False for i in range(s['k'])]
        c = [(resVec_gpu.copy_to_host().tolist()).count(float64(i)) for i in range(s['k'])]
        last_c = [-1 for i in range(s['k'])]
        print(c, last_c)
        while not all(deltaBool):
            c = [(resVec_gpu.copy_to_host().tolist()).count(float64(i)) for i in range(s['k'])]
            deltaBool = [c[i]-last_c[i] == 0 for i in range(s['k'])]
            delta = [last_c[i]-c[i] for i in range(s['k'])]
            print(f"k : {s['k']}, n : {s['n']}, no : {i}, Epochs : {epoch}, Delta : {delta}, range : {max(c)-min(c)}")
            epoch += 1
            last_c = c
            findGroup()
        savetxt(name+f"{max(c)-min(c)}.csv",pinSet_gpu.copy_to_host())
# Out:
# [1013558, 0] [-1, -1]
# k : 2, n : 5, no : 0, Epochs : 1, Delta : [-1013559, -1]
# Min :
#  Counter({1.0: 973416, 0.0: 40142})
# k : 2, n : 5, no : 0, Epochs : 2, Delta : [973416, -973416]
# Min :
#  Counter({1.0: 895847, 0.0: 117711})
# k : 2, n : 5, no : 0, Epochs : 3, Delta : [-77569, 77569]
# Min :
#  Counter({1.0: 805798, 0.0: 207760})
# k : 2, n : 5, no : 0, Epochs : 4, Delta : [-90049, 90049]
# Min :
#  Counter({1.0: 716826, 0.0: 296732})
# k : 2, n : 5, no : 0, Epochs : 5, Delta : [-88972, 88972]
# Min :
#  Counter({1.0: 641840, 0.0: 371718})
# k : 2, n : 5, no : 0, Epochs : 6, Delta : [-74986, 74986]
# Min :
#  Counter({1.0: 594869, 0.0: 418689})
# k : 2, n : 5, no : 0, Epochs : 7, Delta : [-46971, 46971]
# Min :
#  Counter({1.0: 566807, 0.0: 446751})
# k : 2, n : 5, no : 0, Epochs : 8, Delta : [-28062, 28062]
# Min :
#  Counter({1.0: 549344, 0.0: 464214})
# k : 2, n : 5, no : 0, Epochs : 9, Delta : [-17463, 17463]
# Min :
#  Counter({1.0: 537912, 0.0: 475646})
# k : 2, n : 5, no : 0, Epochs : 10, Delta : [-11432, 11432]
# Min :
#  Counter({1.0: 530582, 0.0: 482976})
# k : 2, n : 5, no : 0, Epochs : 11, Delta : [-7330, 7330]
# Min :
#  Counter({1.0: 525491, 0.0: 488067})
# k : 2, n : 5, no : 0, Epochs : 12, Delta : [-5091, 5091]
# Min :
#  Counter({1.0: 522025, 0.0: 491533})
# k : 2, n : 5, no : 0, Epochs : 13, Delta : [-3466, 3466]
# Min :
#  Counter({1.0: 519581, 0.0: 493977})
# k : 2, n : 5, no : 0, Epochs : 14, Delta : [-2444, 2444]
# Min :
#  Counter({1.0: 518021, 0.0: 495537})
# k : 2, n : 5, no : 0, Epochs : 15, Delta : [-1560, 1560]
# Min :
#  Counter({1.0: 517000, 0.0: 496558})
# k : 2, n : 5, no : 0, Epochs : 16, Delta : [-1021, 1021]
# Min :
#  Counter({1.0: 516368, 0.0: 497190})
# k : 2, n : 5, no : 0, Epochs : 17, Delta : [-632, 632]
# Min :
#  Counter({1.0: 515896, 0.0: 497662})
# k : 2, n : 5, no : 0, Epochs : 18, Delta : [-472, 472]
# Min :
#  Counter({1.0: 515493, 0.0: 498065})
# k : 2, n : 5, no : 0, Epochs : 19, Delta : [-403, 403]
# Min :
#  Counter({1.0: 515237, 0.0: 498321})
# k : 2, n : 5, no : 0, Epochs : 20, Delta : [-256, 256]
# Min :
#  Counter({1.0: 515056, 0.0: 498502})
# k : 2, n : 5, no : 0, Epochs : 21, Delta : [-181, 181]
# Min :
#  Counter({1.0: 514921, 0.0: 498637})
# k : 2, n : 5, no : 0, Epochs : 22, Delta : [-135, 135]
# Min :
#  Counter({1.0: 514851, 0.0: 498707})
# k : 2, n : 5, no : 0, Epochs : 23, Delta : [-70, 70]
# Min :
#  Counter({1.0: 514801, 0.0: 498757})
# k : 2, n : 5, no : 0, Epochs : 24, Delta : [-50, 50]
# Min :
#  Counter({1.0: 514763, 0.0: 498795})
# k : 2, n : 5, no : 0, Epochs : 25, Delta : [-38, 38]
# Min :
#  Counter({1.0: 514732, 0.0: 498826})
# k : 2, n : 5, no : 0, Epochs : 26, Delta : [-31, 31]
# Min :
#  Counter({1.0: 514684, 0.0: 498874})
# k : 2, n : 5, no : 0, Epochs : 27, Delta : [-48, 48]
# Min :
#  Counter({1.0: 514648, 0.0: 498910})
# k : 2, n : 5, no : 0, Epochs : 28, Delta : [-36, 36]
# Min :
#  Counter({1.0: 514629, 0.0: 498929})
# k : 2, n : 5, no : 0, Epochs : 29, Delta : [-19, 19]
# Min :
#  Counter({1.0: 514620, 0.0: 498938})
# k : 2, n : 5, no : 0, Epochs : 30, Delta : [-9, 9]
# Min :
#  Counter({1.0: 514613, 0.0: 498945})
# k : 2, n : 5, no : 0, Epochs : 31, Delta : [-7, 7]
# Min :
#  Counter({1.0: 514601, 0.0: 498957})
# k : 2, n : 5, no : 0, Epochs : 32, Delta : [-12, 12]
# Min :
#  Counter({1.0: 514592, 0.0: 498966})
# k : 2, n : 5, no : 0, Epochs : 33, Delta : [-9, 9]
# Min :
#  Counter({1.0: 514589, 0.0: 498969})
# k : 2, n : 5, no : 0, Epochs : 34, Delta : [-3, 3]
# Min :
#  Counter({1.0: 514584, 0.0: 498974})
# k : 2, n : 5, no : 0, Epochs : 35, Delta : [-5, 5]
# Min :
#  Counter({1.0: 514583, 0.0: 498975})
# k : 2, n : 5, no : 0, Epochs : 36, Delta : [-1, 1]
# Min :
#  Counter({1.0: 514583, 0.0: 498975})
# k : 2, n : 5, no : 0, Epochs : 37, Delta : [0, 0]
# Min :
#  Counter({1.0: 514583, 0.0: 498975})
# [1013558, 0] [-1, -1]
# k : 2, n : 5, no : 1, Epochs : 1, Delta : [-1013559, -1]
# Min :
#  Counter({0.0: 983827, 1.0: 29731})
# k : 2, n : 5, no : 1, Epochs : 2, Delta : [29731, -29731]
# Min :
#  Counter({0.0: 903700, 1.0: 109858})
# k : 2, n : 5, no : 1, Epochs : 3, Delta : [80127, -80127]
# Min :
#  Counter({0.0: 808788, 1.0: 204770})
# k : 2, n : 5, no : 1, Epochs : 4, Delta : [94912, -94912]
# Min :
#  Counter({0.0: 722353, 1.0: 291205})
# k : 2, n : 5, no : 1, Epochs : 5, Delta : [86435, -86435]
# Min :
#  Counter({0.0: 651404, 1.0: 362154})
# k : 2, n : 5, no : 1, Epochs : 6, Delta : [70949, -70949]
# Min :
#  Counter({0.0: 598348, 1.0: 415210})
# k : 2, n : 5, no : 1, Epochs : 7, Delta : [53056, -53056]
# Min :
#  Counter({0.0: 561409, 1.0: 452149})
# k : 2, n : 5, no : 1, Epochs : 8, Delta : [36939, -36939]
# Min :
#  Counter({0.0: 536943, 1.0: 476615})
# k : 2, n : 5, no : 1, Epochs : 9, Delta : [24466, -24466]
# Min :
#  Counter({0.0: 521179, 1.0: 492379})
# k : 2, n : 5, no : 1, Epochs : 10, Delta : [15764, -15764]
# Min :
#  Counter({0.0: 511064, 1.0: 502494})
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-54-70696fd0117a> in <module>
#      17         print(c, last_c)
#      18         while not all(deltaBool):
# ---> 19             c = [(resVec_gpu.copy_to_host().tolist()).count(float64(i)) for i in range(s['k'])]
#      20             deltaBool = [c[i]-last_c[i] == 0 for i in range(s['k'])]
#      21             delta = [last_c[i]-c[i] for i in range(s['k'])]
#
# <ipython-input-54-70696fd0117a> in <listcomp>(.0)
#      17         print(c, last_c)
#      18         while not all(deltaBool):
# ---> 19             c = [(resVec_gpu.copy_to_host().tolist()).count(float64(i)) for i in range(s['k'])]
#      20             deltaBool = [c[i]-last_c[i] == 0 for i in range(s['k'])]
#      21             delta = [last_c[i]-c[i] for i in range(s['k'])]
#
# ~\anaconda3\lib\site-packages\numba\cuda\cudadrv\devices.py in _require_cuda_context(*args, **kws)
#     222     def _require_cuda_context(*args, **kws):
#     223         with _runtime.ensure_context():
# --> 224             return fn(*args, **kws)
#     225
#     226     return _require_cuda_context
#
# ~\anaconda3\lib\site-packages\numba\cuda\cudadrv\devicearray.py in copy_to_host(self, ary, stream)
#     259
#     260         if self.alloc_size != 0:
# --> 261             _driver.device_to_host(hostary, self, self.alloc_size,
#     262                                    stream=stream)
#     263
#
# ~\anaconda3\lib\site-packages\numba\cuda\cudadrv\driver.py in device_to_host(dst, src, size, stream)
#    2401         fn = driver.cuMemcpyDtoH
#    2402
# -> 2403     fn(host_pointer(dst), device_pointer(src), size, *varargs)
#    2404
#    2405
#
# ~\anaconda3\lib\site-packages\numba\cuda\cudadrv\driver.py in safe_cuda_api_call(*args)
#     297         def safe_cuda_api_call(*args):
#     298             _logger.debug('call driver api: %s', libfn.__name__)
# --> 299             retcode = libfn(*args)
#     300             self._check_error(fname, retcode)
#     301         return safe_cuda_api_call
#
# KeyboardInterrupt:

# %%
print(pinSet_gpu.copy_to_host())

# %%
savetxt("pinSet_k2_n1m_r80k_full.csv",pinSet_gpu.copy_to_host())

# %%
dataset_gpu = None
pinSet_gpu = None
resTensor_gpu = None
SumArray_gpu = None
resVec_gpu = None
resVec = np.zeros(dataset.shape[0])
SumArray = np.zeros((dataset.shape[0],pinSet.shape[0]))
dataset_gpu = cuda.to_device(dataset)
pinSet_gpu = cuda.to_device(pinSet)
resTensor_gpu = cuda.to_device(resTensor)
SumArray_gpu = cuda.to_device(SumArray)
resVec_gpu = cuda.to_device(resVec)
